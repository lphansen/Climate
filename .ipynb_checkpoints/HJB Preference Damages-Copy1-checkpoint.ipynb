# %%
# Required packages
import numpy as np
import pandas as pd
from scipy.io import loadmat
from scipy.stats import norm
import pdb
import warnings
import SolveLinSys
import time
import sys
sys.stdout.flush()
import line_profiler
# %load_ext line_profiler

# %%
# Data Cleansing
x = loadmat('climate_pars.mat')

# %%
for key,val in x.items():
    if key[0:2] == '__':
        pass
    elif key == 'filename' or key == 's' or key == 's0' or key =='s1' or key == 's2':
        pass
    else:
        (height, width) = val.shape
        if width == 1:
            
            
            if height == 1:    # one number
                exec(key +'=val[0,0]')
            else:              # a column array
                exec(key +'=val[:,0]')
        else:
            if height == 1:    # a row array
                exec(key +'=val[0,:]')
            else:
                exec(key +'=val')

# %%
def centra_diff(data, dim, order, dlt, cap = None):  # compute the central difference derivatives for given input and dimensions
    res = np.zeros(data.shape)
    if order == 1:                    # first order derivatives
        
        if dim == 0:                  # to first dimension

            res[1:-1,:,:] = (1 / (2 * dlt)) * (data[2:,:,:] - data[:-2,:,:])
            res[-1,:,:] = (1 / dlt) * (data[-1,:,:] - data[-2,:,:])
            res[0,:,:] = (1 / dlt) * (data[1,:,:] - data[0,:,:])

        elif dim == 1:                # to second dimension

            res[:,1:-1,:] = (1 / (2 * dlt)) * (data[:,2:,:] - data[:,:-2,:])
            res[:,-1,:] = (1 / dlt) * (data[:,-1,:] - data[:,-2,:])
            res[:,0,:] = (1 / dlt) * (data[:,1,:] - data[:,0,:])

        elif dim == 2:                # to third dimension

            res[:,:,1:-1] = (1 / (2 * dlt)) * (data[:,:,2:] - data[:,:,:-2])
            res[:,:,-1] = (1 / dlt) * (data[:,:,-1] - data[:,:,-2])
            res[:,:,0] = (1 / dlt) * (data[:,:,1] - data[:,:,0])

        else:
            raise ValueError('wrong dim')
            
    elif order == 2:
        
        if dim == 0:                  # to first dimension

            res[1:-1,:,:] = (1 / dlt ** 2) * (data[2:,:,:] + data[:-2,:,:] - 2 * data[1:-1,:,:])
            res[-1,:,:] = (1 / dlt ** 2) * (data[-1,:,:] + data[-3,:,:] - 2 * data[-2,:,:])
            res[0,:,:] = (1 / dlt ** 2) * (data[2,:,:] + data[0,:,:] - 2 * data[1,:,:])

        elif dim == 1:                # to second dimension

            res[:,1:-1,:] = (1 / dlt ** 2) * (data[:,2:,:] + data[:,:-2,:] - 2 * data[:,1:-1,:])
            res[:,-1,:] = (1 / dlt ** 2) * (data[:,-1,:] + data[:,-3,:] - 2 * data[:,-2,:])
            res[:,0,:] = (1 / dlt ** 2) * (data[:,2,:] + data[:,0,:] - 2 * data[:,1,:])

        elif dim == 2:                # to third dimension

            res[:,:,1:-1] = (1 / dlt ** 2) * (data[:,:,2:] + data[:,:,:-2] - 2 * data[:,:,1:-1])
            res[:,:,-1] = (1 / dlt ** 2) * (data[:,:,-1] + data[:,:,-3] - 2 * data[:,:,-2])
            res[:,:,0] = (1 / dlt ** 2) * (data[:,:,2] + data[:,:,0] - 2 * data[:,:,1])

        else:
            raise ValueError('wrong dim')
        
    else:
        raise ValueError('wrong order')
        
    if cap is not None:
        res[res < cap] = cap
    return res

# %%
def quad_points_legendre(n):
    u = np.sqrt(1 / (4 - 1 / np.linspace(1,n-1,n-1)**2))  # upper diag
    [lambda0,V] = np.linalg.eig(np.diagflat(u,1) + np.diagflat(u,-1))  # V's column vectors are the main d
    i = np.argsort(lambda0)
    Vtop = V[0,:]
    Vtop = Vtop[i]
    w = 2 * Vtop ** 2
    return (lambda0[i],w)

def quad_points_hermite(n):
    i = np.linspace(1,n-1,n-1)
    a = np.sqrt(i / 2.0)
    [lambda0,V] = np.linalg.eig(np.diagflat(a,1) + np.diagflat(a,-1))
    i = np.argsort(lambda0)
    Vtop = V[0,:]
    Vtop = Vtop[i]
    w = np.sqrt(np.pi) * Vtop ** 2
    return (lambda0[i],w)


def quad_int(f,a,b,n,method):
    """
This function takes a function f to integrate from the multidimensional
interval specified by the row vectors a and b. N different points are used
in the quadrature method. Legendre and Hermite basis functions are
currently supported. In the case of Hermite methodology b is the normal
density and a is the normal mean.

Created by John Wilson (johnrwilson@uchicago.edu) & Updaed by Jiaming Wang (Jiamingwang@uchicago.edu)
    """
    if method == 'legendre':
        
        (xs,ws) = quad_points_legendre(n)
        g = lambda x: f((b-a) * 0.5  * x + (a + b) * 0.5)
        s = np.prod((b-a) * 0.5)                ######## Why using prod here?
        
    elif method == 'hermite':
        
        (xs,ws) = quad_points_hermite(n)
        g = lambda x: f(np.sqrt(2) * b * x + a)
        s = 1 / np.sqrt(np.pi)
        
    else:
        raise TypeError('Wrong polynomials specification')
    
    
    tp = type(a)
    if tp is np.float64 or tp is int or tp is np.double:
        res = 0
        for i in range(n):
#             pdb.set_trace()
            res += ws[i] * g(xs[i])
    else:
        raise ValueError('dimension is not 1')
    
    return s * res

# %%
start_time = time.time()

quadrature = 'legendre'   ###
theta = 5000
weight = 0.5

sigma_o = sigma_k
indic = 0    # redundant
beta_f = np.mean(par_lambda_McD)
var_beta_f = np.var(par_lambda_McD)
#     var_beta_f = for_check['var_beta_f'][0][0]               # Worth discussion further
par_beta_f = par_lambda_McD
lambda0 = 1.0 / var_beta_f   # noted as lambda in MATLAB

xi_d = -1 * (1-alpha)
r_min = 0
r_max = 9
t_min = 0
t_max = 4000
k_min = 0
k_max = 9

tol = 1e-3

nr = 30
nt = 30
nk = 25
r = np.linspace(r_min, r_max, nr)
t = np.linspace(t_min, t_max, nt)
k = np.linspace(k_min, k_max, nk)

hr = r[1] - r[0]
hk = k[1] - k[0]
ht = t[1] - t[0]

(r_mat, t_mat, k_mat) = np.meshgrid(r,t,k, indexing = 'ij')
# r_mat = for_check['r_mat']
# t_mat = for_check['t_mat']
# k_mat = for_check['k_mat']

# time step
dt = 0.5
n = 30

# Power selection
power = 2


if power == 2:
    # Quad, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 2 * 0.0197
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0
elif power == 3:
    # Cubic, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 3 * 0.0079 * 1.5
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0

f_bar = 2
crit = 2

F0 = 1
sigma = np.matrix([[sigma_1 ** 2, rho_12], [rho_12, sigma_2 ** 2]])
Sigma = np.matrix([[var_beta_f,0,0],[0,sigma_1 ** 2, rho_12],[0, rho_12, sigma_2 ** 2]])
dee = np.matrix([gamma_1 + gamma_2 * F0 + gamma_2_plus * (F0 - f_bar) ** 2 * (F0>=2), beta_f, beta_f * F0])
sigma_d = float(np.sqrt(dee * Sigma * dee.T))

weight = 0.5  # on nordhaus
bar_gamma_2_plus = weight * 0 + (1 - weight) * gamma_2_plus

a = beta_f - 5 * np.sqrt(var_beta_f)
b = beta_f + 5 * np.sqrt(var_beta_f)

step_val1 = round(len(r) / 5)
step_val2 = round(len(t) / 5)
step_val3 = round(len(k) / 5)

v0 = alpha * r_mat + (1-alpha) * k_mat - beta_f * t_mat
v1_initial = v0 * np.ones(r_mat.shape)

v0_dr = centra_diff(v0,0,1,hr,1e-8)
v0_dt = centra_diff(v0,1,1,ht)
v0_dk = centra_diff(v0,2,1,hk)

v0_drr = centra_diff(v0,0,2,hr)
v0_dtt = centra_diff(v0,1,2,ht)
v0_dkk = centra_diff(v0,2,2,hk)

### FOC_all combinations
B1 = v0_dr - xi_d * (gamma_1 + gamma_2 * t_mat * beta_f + gamma_2_plus * (t_mat * beta_f - f_bar) ** (power - 1) * (t_mat >= (crit / beta_f))) * beta_f * np.exp(r_mat) - v0_dt * np.exp(r_mat)
C1 = - delta * alpha
e = -C1 / B1
e_hat = e
Acoeff = np.exp(r_mat - k_mat)
Bcoeff = delta * (1-alpha) / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5) + v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)
Ccoeff = -A_O  - Theta
f = ((-Bcoeff + np.sqrt(Bcoeff ** 2 - 4 * Acoeff * Ccoeff)) / (2 * Acoeff)) ** 2
i_k = (v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)) * (f ** 0.5) - Theta

# lower damage model:
a_1 = np.zeros(r_mat.shape);
b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
lambda_tilde_1 = lambda0 + c_1 * theta
beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1
I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta
#     R_1 = theta.*(I_1-(a_1+b_1.*beta_tilde_1+c_1./2.*(beta_tilde_1).^2+c_1./2./lambda_tilde_1));
R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)

# J_1_without_e = xi_d.*(gamma_1.*beta_tilde_1 ...
#         +gamma_2.*t_mat.*(beta_tilde_1.^2+1./lambda_tilde_1)).*exp(r_mat) ;

pi_tilde_1 = weight * np.exp(-theta * I_1)

r_multi = np.exp(r)
r_multi = r_multi[:,np.newaxis,np.newaxis]

# high damage model
if quadrature == 'legendre':

    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

elif quadrature == 'hermite':

    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

else: 

    raise TypeError('Wrong polynomials specification')

q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
I_2 = -1 / theta * np.log(scale_2)

#     q2_tilde_fnc = @(x) exp(-theta.*xi_d.*(gamma_1.*x ...
#         +gamma_2.*x.^2.*t_mat ...
#         +gamma_2_plus.*x.*(x.*t_mat-f_bar).^(power-1).*((x.*t_mat-f_bar)>=0)).*exp(r).*e_hat)./scale_2;

if quadrature == 'legendre':

    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

elif quadrature == 'hermite':

    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

J_2_with_e = J_2_without_e * e_hat

R_2 = theta * (I_2 - J_2_with_e)
pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
pi_tilde_2_norm = 1 - pi_tilde_1_norm

expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
C1 = -delta * alpha
e = -C1 / B1
e_star = e

J_1 = J_1_without_e * e_star
J_2 = J_2_without_e * e_star

I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

R_1 = theta * (I_1 - J_1)
R_2 = theta * (I_2 - J_2)
drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
RE_total = 1 / theta * RE

### PDE Inputs

A = -delta * np.ones(r_mat.shape)
B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
B_t = e_star * np.exp(r_mat)
C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
C_tt = np.zeros(r_mat.shape)

D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) + I_term #  + drift_distort + RE_total

stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
A = A.reshape(-1,1,order = 'F')
B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
D = D.reshape(-1,1,order = 'F')
v01 = v0.reshape(-1,1,order = 'F')
dt = dt
temp = v0
out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)

out_comp = out.reshape(v0.shape,order = "F")
episode = 0

print("Episode %d: PDE Error: %f" %(episode, np.max((out_comp - v0) / dt))) #Conjugate Gradient Error %f after %d iterations" % (episode, np.max((out_comp - v0) / dt), out[1], out[0]))

vold = v1_initial

while np.max((out_comp - vold) / dt) > tol:
# for iter in range(1):
    vold = v0
    v0 = out_comp
    v0_dr = centra_diff(v0,0,1,hr,1e-8)
    v0_dt = centra_diff(v0,1,1,ht)
    v0_dk = centra_diff(v0,2,1,hk)

    v0_drr = centra_diff(v0,0,2,hr)
    v0_dtt = centra_diff(v0,1,2,ht)
    v0_dkk = centra_diff(v0,2,2,hk)

    e_hat = e_star 

    f = ((A_O + Theta) * np.exp(-r_mat + k_mat) * (v0_dr * Gamma_r * Theta_r) / ((v0_dr * Gamma_r * Theta_r) * f ** (Theta_r) + (delta * (1-alpha) + v0_dk * Gamma))) ** (1 / (1 - Theta_r))
    f = f * (v0_dr > 1e-8)
    i_k = ((v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * Theta_r)) * (f ** (1 - Theta_r)) - Theta) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * Gamma * A_O - delta * (1-alpha) * Theta) / (delta * (1-alpha) + v0_dk * Gamma)

    # lower damage model:
    a_1 = np.zeros(r_mat.shape);
    b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
    c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
    lambda_tilde_1 = lambda0 + c_1 * theta
    beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1

    I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta

    R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
    J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)
    pi_tilde_1 = weight * np.exp(-theta * I_1)  

    #     r_multi = np.exp(r)
    #     r_multi = r_multi[:,np.newaxis,np.newaxis]

    ## high damage model
    if quadrature == 'legendre':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

    elif quadrature == 'hermite':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    else: 

        raise TypeError('Wrong polynomials specification')

    q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
    I_2 = -1 / theta * np.log(scale_2)

    if quadrature == 'legendre':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

    elif quadrature == 'hermite':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    J_2_with_e = J_2_without_e * e_hat
    R_2 = theta * (I_2 - J_2_with_e)
    pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
    pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
    pi_tilde_2_norm = 1 - pi_tilde_1_norm

    expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

    B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
    C1 = -delta * alpha
    e = -C1 / B1
    e_star = e

    J_1 = J_1_without_e * e_star
    J_2 = J_2_without_e * e_star

    I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

    R_1 = theta * (I_1 - J_1)
    R_2 = theta * (I_2 - J_2)
    drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

    RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
    RE_total = 1 / theta * RE 

    ### PDE Inputs

    A = -delta * np.ones(r_mat.shape)
    B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
    B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
    B_t = e_star * np.exp(r_mat)
    C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
    C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
    C_tt = np.zeros(r_mat.shape)

    D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) +  I_term # + drift_distort + RE_total

    stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
    A = A.reshape(-1,1,order = 'F')
    B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
    C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
    D = D.reshape(-1,1,order = 'F')
    v01 = v0.reshape(-1,1,order = 'F')
    dt = dt

    out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
    out_comp = out.reshape(v0.shape,order = "F")
    episode += 1

    v0 = out_comp
    print("Episode %d: PDE Error: %f" %(episode, np.max((out_comp - vold) / dt)))

    # print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Episode 0: PDE Error: 0.054144
# Episode 1: PDE Error: 0.108243
# Episode 2: PDE Error: 0.088406
# Episode 3: PDE Error: 0.088143
# Episode 4: PDE Error: 0.087882
# Episode 5: PDE Error: 0.087621
# Episode 6: PDE Error: 0.087362
# Episode 7: PDE Error: 0.087104
# Episode 8: PDE Error: 0.086848
# Episode 9: PDE Error: 0.086593
# Episode 10: PDE Error: 0.086339
# Episode 11: PDE Error: 0.086086
# Episode 12: PDE Error: 0.085835
# Episode 13: PDE Error: 0.085584
# Episode 14: PDE Error: 0.085336
# Episode 15: PDE Error: 0.085088
# Episode 16: PDE Error: 0.084841
# Episode 17: PDE Error: 0.084596
# Episode 18: PDE Error: 0.084352
# Episode 19: PDE Error: 0.084109
# Episode 20: PDE Error: 0.083868
# Episode 21: PDE Error: 0.083627
# Episode 22: PDE Error: 0.083388
# Episode 23: PDE Error: 0.083150
# Episode 24: PDE Error: 0.082913
# Episode 25: PDE Error: 0.082678
# Episode 26: PDE Error: 0.082443
# Episode 27: PDE Error: 0.082210
# Episode 28: PDE Error: 0.081978
# Episode 29: PDE Error: 0.081747
# Episode 30: PDE Error: 0.081517
# Episode 31: PDE Error: 0.081288
# Episode 32: PDE Error: 0.081061
# Episode 33: PDE Error: 0.080834
# Episode 34: PDE Error: 0.080609
# Episode 35: PDE Error: 0.080385
# Episode 36: PDE Error: 0.080162
# Episode 37: PDE Error: 0.079940
# Episode 38: PDE Error: 0.079719
# Episode 39: PDE Error: 0.079499
# Episode 40: PDE Error: 0.079281
# Episode 41: PDE Error: 0.079063
# Episode 42: PDE Error: 0.078846
# Episode 43: PDE Error: 0.078631
# Episode 44: PDE Error: 0.078417
# Episode 45: PDE Error: 0.078203
# Episode 46: PDE Error: 0.077991
# Episode 47: PDE Error: 0.077780
# Episode 48: PDE Error: 0.077570
# Episode 49: PDE Error: 0.077361
# Episode 50: PDE Error: 0.077153
# Episode 51: PDE Error: 0.076946
# Episode 52: PDE Error: 0.076740
# Episode 53: PDE Error: 0.076535
# Episode 54: PDE Error: 0.076331
# Episode 55: PDE Error: 0.076128
# Episode 56: PDE Error: 0.075926
# Episode 57: PDE Error: 0.075725
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7e728e0f6d5b> in <module>
#     318     dt = dt
#     319
# --> 320     out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
#     321     out_comp = out.reshape(v0.shape,order = "F")
#     322     episode += 1
#
# KeyboardInterrupt:

# %%
temp == v0
# Out:
# array([[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]])

# %%
for_check = loadmat("temp_check.mat")

# %%
mdl = for_check['model']

# %%
np.max(abs(mdl['B'][0,0] - B))
# Out:
# 0.11128537693110055

# %%
np.max(abs(for_check['out_comp'] - out_comp))
# Out:
# 2.4175112134372512e-08

# %%
while np.max((out_comp - vold) / dt) > tol:
# for iter in range(1):
    vold = v0
    v0_dr = centra_diff(v0,0,1,hr,1e-8)
    v0_dt = centra_diff(v0,1,1,ht)
    v0_dk = centra_diff(v0,2,1,hk)

    v0_drr = centra_diff(v0,0,2,hr)
    v0_dtt = centra_diff(v0,1,2,ht)
    v0_dkk = centra_diff(v0,2,2,hk)

    e_hat = e_star 

    f = ((A_O + Theta) * np.exp(-r_mat + k_mat) * (v0_dr * Gamma_r * Theta_r) / ((v0_dr * Gamma_r * Theta_r) * f ** (Theta_r) + (delta * (1-alpha) + v0_dk * Gamma))) ** (1 / (1 - Theta_r))
    f = f * (v0_dr > 1e-8)
    i_k = ((v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * Theta_r)) * (f ** (1 - Theta_r)) - Theta) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * Gamma * A_O - delta * (1-alpha) * Theta) / (delta * (1-alpha) + v0_dk * Gamma)

    # lower damage model:
    a_1 = np.zeros(r_mat.shape);
    b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
    c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
    lambda_tilde_1 = lambda0 + c_1 * theta
    beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1

    I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta

    R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
    J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)
    pi_tilde_1 = weight * np.exp(-theta * I_1)  

    #     r_multi = np.exp(r)
    #     r_multi = r_multi[:,np.newaxis,np.newaxis]

    ## high damage model
    if quadrature == 'legendre':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

    elif quadrature == 'hermite':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    else: 

        raise TypeError('Wrong polynomials specification')

    q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
    I_2 = -1 / theta * np.log(scale_2)

    if quadrature == 'legendre':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

    elif quadrature == 'hermite':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    J_2_with_e = J_2_without_e * e_hat
    R_2 = theta * (I_2 - J_2_with_e)
    pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
    pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
    pi_tilde_2_norm = 1 - pi_tilde_1_norm

    expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

    B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
    C1 = -delta * alpha
    e = -C1 / B1
    e_star = e

    J_1 = J_1_without_e * e_star
    J_2 = J_2_without_e * e_star

    I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

    R_1 = theta * (I_1 - J_1)
    R_2 = theta * (I_2 - J_2)
    drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

    RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
    RE_total = 1 / theta * RE 

    ### PDE Inputs

    A = -delta * np.ones(r_mat.shape)
    B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
    B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
    B_t = e_star * np.exp(r_mat)
    C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
    C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
    C_tt = np.zeros(r_mat.shape)

    D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) +  I_term # + drift_distort + RE_total

    stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
    A = A.reshape(-1,1,order = 'F')
    B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
    C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
    D = D.reshape(-1,1,order = 'F')
    v01 = v0.reshape(-1,1,order = 'F')
    dt = dt

    out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
    out_comp = out.reshape(v0.shape,order = "F")
    episode += 1

    v0 = out_comp
    print("Episode %d: PDE Error: %f" %(episode, np.max((out_comp - vold) / dt)))

    # print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Episode 1: PDE Error: 0.057650
# Episode 2: PDE Error: 0.057267
# Episode 3: PDE Error: 0.056872
# Episode 4: PDE Error: 0.056483
# Episode 5: PDE Error: 0.056101
# Episode 6: PDE Error: 0.055725
# Episode 7: PDE Error: 0.055355
# Episode 8: PDE Error: 0.054990
# Episode 9: PDE Error: 0.054631
# Episode 10: PDE Error: 0.054277
# Episode 11: PDE Error: 0.053928
# Episode 12: PDE Error: 0.053584
# Episode 13: PDE Error: 0.053244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-efa2a76a2b1e> in <module>
#     105     dt = dt
#     106
# --> 107     out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
#     108     out_comp = out.reshape(v0.shape,order = "F")
#     109     episode += 1
#
# KeyboardInterrupt:

# %%
for_check3 = loadmat("temp_check3.mat")
mdl3 = for_check3['model']

# %%
np.max(abs(for_check3['out_comp'] - out_comp))
# Out:
# 4.504698480900515e-08

# %%
np.max(abs(mdl3['C'][0,0] - C))
# Out:
# 0.0

# %%
def prof_function():
    x = loadmat("climate_pars.mat")
    for key,val in x.items():
        if key[0:2] == '__':
            pass
        elif key == 'filename' or key == 's' or key == 's0' or key =='s1' or key == 's2':
            pass
        else:
            (height, width) = val.shape
            if width == 1:
                if height == 1:    # one number
                    exec(key +'=val[0,0]')
                else:              # a column array
                    exec(key +'=val[:,0]')
            else:
                if height == 1:    # a row array
                    exec(key +'=val[0,:]')
                else:
                    exec(key +'=val')


    start_time = time.time()

    quadrature = 'legendre'   ###
    theta = 5000
    weight = 0.5

    sigma_o = sigma_k
    indic = 0    # redundant
    beta_f = np.mean(par_lambda_McD)
    var_beta_f = np.var(par_lambda_McD)
    #     var_beta_f = for_check['var_beta_f'][0][0]               # Worth discussion further
    par_beta_f = par_lambda_McD
    lambda0 = 1.0 / var_beta_f   # noted as lambda in MATLAB

    xi_d = -1 * (1-alpha)
    r_min = 0
    r_max = 9
    t_min = 0
    t_max = 4000
    k_min = 0
    k_max = 9

    tol = 1e-3

    nr = 30
    nt = 30
    nk = 25
    r = np.linspace(r_min, r_max, nr)
    t = np.linspace(t_min, t_max, nt)
    k = np.linspace(k_min, k_max, nk)

    hr = r[1] - r[0]
    hk = k[1] - k[0]
    ht = t[1] - t[0]

    (r_mat, t_mat, k_mat) = np.meshgrid(r,t,k, indexing = 'ij')
    # r_mat = for_check['r_mat']
    # t_mat = for_check['t_mat']
    # k_mat = for_check['k_mat']

    # time step
    dt = 0.5
    n = 30

    # Power selection
    power = 2


    if power == 2:
        # Quad, max temp = 5:
        gamma_1 =  0.00017675
        gamma_2 =  2 * 0.0022
        gamma_2_plus = 2 * 0.0197
        sigma_1 = 0
        sigma_2 = 0
        rho_12 = 0
    elif power == 3:
        # Cubic, max temp = 5:
        gamma_1 =  0.00017675
        gamma_2 =  2 * 0.0022
        gamma_2_plus = 3 * 0.0079 * 1.5
        sigma_1 = 0
        sigma_2 = 0
        rho_12 = 0

    f_bar = 2
    crit = 2

    F0 = 1
    sigma = np.matrix([[sigma_1 ** 2, rho_12], [rho_12, sigma_2 ** 2]])
    Sigma = np.matrix([[var_beta_f,0,0],[0,sigma_1 ** 2, rho_12],[0, rho_12, sigma_2 ** 2]])
    dee = np.matrix([gamma_1 + gamma_2 * F0 + gamma_2_plus * (F0 - f_bar) ** 2 * (F0>=2), beta_f, beta_f * F0])
    sigma_d = float(np.sqrt(dee * Sigma * dee.T))

    weight = 0.5  # on nordhaus
    bar_gamma_2_plus = weight * 0 + (1 - weight) * gamma_2_plus

    a = beta_f - 5 * np.sqrt(var_beta_f)
    b = beta_f + 5 * np.sqrt(var_beta_f)

    step_val1 = round(len(r) / 5)
    step_val2 = round(len(t) / 5)
    step_val3 = round(len(k) / 5)

    v0 = alpha * r_mat + (1-alpha) * k_mat - beta_f * t_mat
    v1_initial = v0 * np.ones(r_mat.shape)

    v0_dr = centra_diff(v0,0,1,hr,1e-8)
    v0_dt = centra_diff(v0,1,1,ht)
    v0_dk = centra_diff(v0,2,1,hk)

    v0_drr = centra_diff(v0,0,2,hr)
    v0_dtt = centra_diff(v0,1,2,ht)
    v0_dkk = centra_diff(v0,2,2,hk)

    ### FOC_all combinations
    B1 = v0_dr - xi_d * (gamma_1 + gamma_2 * t_mat * beta_f + gamma_2_plus * (t_mat * beta_f - f_bar) ** (power - 1) * (t_mat >= (crit / beta_f))) * beta_f * np.exp(r_mat) - v0_dt * np.exp(r_mat)
    C1 = - delta * alpha
    e = -C1 / B1
    e_hat = e
    Acoeff = np.exp(r_mat - k_mat)
    Bcoeff = delta * (1-alpha) / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5) + v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)
    Ccoeff = -A_O  - Theta
    f = ((-Bcoeff + np.sqrt(Bcoeff ** 2 - 4 * Acoeff * Ccoeff)) / (2 * Acoeff)) ** 2
    i_k = (v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)) * (f ** 0.5) - Theta

    # lower damage model:
    a_1 = np.zeros(r_mat.shape);
    b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
    c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
    lambda_tilde_1 = lambda0 + c_1 * theta
    beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1
    I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta
    #     R_1 = theta.*(I_1-(a_1+b_1.*beta_tilde_1+c_1./2.*(beta_tilde_1).^2+c_1./2./lambda_tilde_1));
    R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
    J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)

    # J_1_without_e = xi_d.*(gamma_1.*beta_tilde_1 ...
    #         +gamma_2.*t_mat.*(beta_tilde_1.^2+1./lambda_tilde_1)).*exp(r_mat) ;

    pi_tilde_1 = weight * np.exp(-theta * I_1)

    r_multi = np.exp(r)
    r_multi = r_multi[:,np.newaxis,np.newaxis]

    # high damage model
    if quadrature == 'legendre':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

    elif quadrature == 'hermite':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    else: 

        raise TypeError('Wrong polynomials specification')

    q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
    I_2 = -1 / theta * np.log(scale_2)

    #     q2_tilde_fnc = @(x) exp(-theta.*xi_d.*(gamma_1.*x ...
    #         +gamma_2.*x.^2.*t_mat ...
    #         +gamma_2_plus.*x.*(x.*t_mat-f_bar).^(power-1).*((x.*t_mat-f_bar)>=0)).*exp(r).*e_hat)./scale_2;

    if quadrature == 'legendre':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

    elif quadrature == 'hermite':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    J_2_with_e = J_2_without_e * e_hat

    R_2 = theta * (I_2 - J_2_with_e)
    pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
    pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
    pi_tilde_2_norm = 1 - pi_tilde_1_norm

    expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

    B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
    C1 = -delta * alpha
    e = -C1 / B1
    e_star = e

    J_1 = J_1_without_e * e_star
    J_2 = J_2_without_e * e_star

    I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

    R_1 = theta * (I_1 - J_1)
    R_2 = theta * (I_2 - J_2)
    drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

    RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
    RE_total = 1 / theta * RE

    ### PDE Inputs

    A = -delta * np.ones(r_mat.shape)
    B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
    B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
    B_t = e_star * np.exp(r_mat)
    C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
    C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
    C_tt = np.zeros(r_mat.shape)

    D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) + I_term #  + drift_distort + RE_total

    stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
    A = A.reshape(-1,1,order = 'F')
    B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
    C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
    D = D.reshape(-1,1,order = 'F')
    v01 = v0.reshape(-1,1,order = 'F')
    dt = dt

    out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)

    out_comp = out.reshape(v0.shape,order = "F")
    episode = 0

    print("Episode %d: PDE Error: %f", %(episode, np.max((out_comp - v0) / dt))) #Conjugate Gradient Error %f after %d iterations" % (episode, np.max((out_comp - v0) / dt), out[1], out[0]))
    v0 = out_comp
    vold = v1_initial
    
    while np.max((out_comp - vold) / dt) > tol:
    # for iter in range(1):
        vold = v0
        v0_dr = centra_diff(v0,0,1,hr,1e-8)
        v0_dt = centra_diff(v0,1,1,ht)
        v0_dk = centra_diff(v0,2,1,hk)

        v0_drr = centra_diff(v0,0,2,hr)
        v0_dtt = centra_diff(v0,1,2,ht)
        v0_dkk = centra_diff(v0,2,2,hk)

        e_hat = e_star 

        f = ((A_O + Theta) * np.exp(-r_mat + k_mat) * (v0_dr * Gamma_r * Theta_r) / ((v0_dr * Gamma_r * Theta_r) * f ** (Theta_r) + (delta * (1-alpha) + v0_dk * Gamma))) ** (1 / (1 - Theta_r))
        f = f * (v0_dr > 1e-8)
        i_k = ((v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * Theta_r)) * (f ** (1 - Theta_r)) - Theta) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * Gamma * A_O - delta * (1-alpha) * Theta) / (delta * (1-alpha) + v0_dk * Gamma)

        # lower damage model:
        a_1 = np.zeros(r_mat.shape);
        b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
        c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
        lambda_tilde_1 = lambda0 + c_1 * theta
        beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1

        I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta

        R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
        J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)
        pi_tilde_1 = weight * np.exp(-theta * I_1)  

        #     r_multi = np.exp(r)
        #     r_multi = r_multi[:,np.newaxis,np.newaxis]

        ## high damage model
        if quadrature == 'legendre':

            scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

        elif quadrature == 'hermite':

            scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

        else: 

            raise TypeError('Wrong polynomials specification')

        q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
        I_2 = -1 / theta * np.log(scale_2)

        if quadrature == 'legendre':

            J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

        elif quadrature == 'hermite':

            J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

        J_2_with_e = J_2_without_e * e_hat
        R_2 = theta * (I_2 - J_2_with_e)
        pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
        pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
        pi_tilde_2_norm = 1 - pi_tilde_1_norm

        expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

        B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
        C1 = -delta * alpha
        e = -C1 / B1
        e_star = e

        J_1 = J_1_without_e * e_star
        J_2 = J_2_without_e * e_star

        I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

        R_1 = theta * (I_1 - J_1)
        R_2 = theta * (I_2 - J_2)
        drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

        RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
        RE_total = 1 / theta * RE 

        ### PDE Inputs

        A = -delta * np.ones(r_mat.shape)
        B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
        B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
        B_t = e_star * np.exp(r_mat)
        C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
        C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
        C_tt = np.zeros(r_mat.shape)

        D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) +  I_term # + drift_distort + RE_total

        stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
        A = A.reshape(-1,1,order = 'F')
        B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
        C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
        D = D.reshape(-1,1,order = 'F')
        v01 = v0.reshape(-1,1,order = 'F')
        dt = dt

        out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
        out_comp = out.reshape(v0.shape,order = "F")
        episode += 1

        v0 = out_comp
        print("Episode %d: PDE Error: %f", %(episode, np.max((out_comp - vold) / dt)))
        
    print("--- %s seconds ---" % (time.time() - start_time))

# %%
for_check = loadmat("")

# %%
# %lprun -f prof_function prof_function()
# Out:
# Episode %d: PDE Error: %f (0, 0.054144438590462585)
# Episode %d: PDE Error: %f (1, 0.0)
# Episode %d: PDE Error: %f (2, 0.0)
# Episode %d: PDE Error: %f (3, 0.0)
# Episode %d: PDE Error: %f (4, 0.0)
# Episode %d: PDE Error: %f (5, 0.0)
# Episode %d: PDE Error: %f (6, 0.0)
# Episode %d: PDE Error: %f (7, 0.0)
# Episode %d: PDE Error: %f (8, 0.0)
# Episode %d: PDE Error: %f (9, 0.0)
# Episode %d: PDE Error: %f (10, 0.0)
# Episode %d: PDE Error: %f (11, 0.0)
# Episode %d: PDE Error: %f (12, 0.0)
# Episode %d: PDE Error: %f (13, 0.0)
# Episode %d: PDE Error: %f (14, 0.0)
# Episode %d: PDE Error: %f (15, 0.0)
# Episode %d: PDE Error: %f (16, 0.0)
# Episode %d: PDE Error: %f (17, 0.0)
# Episode %d: PDE Error: %f (18, 0.0)
# Episode %d: PDE Error: %f (19, 0.0)
# Episode %d: PDE Error: %f (20, 0.0)
# Episode %d: PDE Error: %f (21, 0.0)
# Episode %d: PDE Error: %f (22, 0.0)
# Episode %d: PDE Error: %f (23, 0.0)
# Episode %d: PDE Error: %f (24, 0.0)
# Episode %d: PDE Error: %f (25, 0.0)
# Episode %d: PDE Error: %f (26, 0.0)
# Episode %d: PDE Error: %f (27, 0.0)
# Episode %d: PDE Error: %f (28, 0.0)
# Episode %d: PDE Error: %f (29, 0.0)
# Episode %d: PDE Error: %f (30, 0.0)
# Episode %d: PDE Error: %f (31, 0.0)
# Episode %d: PDE Error: %f (32, 0.0)
# Episode %d: PDE Error: %f (33, 0.0)
# Episode %d: PDE Error: %f (34, 0.0)
# Episode %d: PDE Error: %f (35, 0.0)
# Episode %d: PDE Error: %f (36, 0.0)
# Episode %d: PDE Error: %f (37, 0.0)
# Episode %d: PDE Error: %f (38, 0.0)
# Episode %d: PDE Error: %f (39, 0.0)
# Episode %d: PDE Error: %f (40, 0.0)
# Episode %d: PDE Error: %f (41, 0.0)
# Episode %d: PDE Error: %f (42, 0.0)
# Episode %d: PDE Error: %f (43, 0.0)
# Episode %d: PDE Error: %f (44, 0.0)
# Episode %d: PDE Error: %f (45, 0.0)
# Episode %d: PDE Error: %f (46, 0.0)
# Episode %d: PDE Error: %f (47, 0.0)
# Episode %d: PDE Error: %f (48, 0.0)
# Episode %d: PDE Error: %f (49, 0.0)
# Episode %d: PDE Error: %f (50, 0.0)
# Episode %d: PDE Error: %f (51, 0.0)
# Episode %d: PDE Error: %f (52, 0.0)
# Episode %d: PDE Error: %f (53, 0.0)
# Episode %d: PDE Error: %f (54, 0.0)
# Episode %d: PDE Error: %f (55, 0.0)
# Episode %d: PDE Error: %f (56, 0.0)
# Episode %d: PDE Error: %f (57, 0.0)
# Episode %d: PDE Error: %f (58, 0.0)
# Episode %d: PDE Error: %f (59, 0.0)
# Episode %d: PDE Error: %f (60, 0.0)
# Episode %d: PDE Error: %f (61, 0.0)
# Episode %d: PDE Error: %f (62, 0.0)
# Episode %d: PDE Error: %f (63, 0.0)
# Episode %d: PDE Error: %f (64, 0.0)
# Episode %d: PDE Error: %f (65, 0.0)
# Episode %d: PDE Error: %f (66, 0.0)
# Episode %d: PDE Error: %f (67, 0.0)
# Episode %d: PDE Error: %f (68, 0.0)
# Episode %d: PDE Error: %f (69, 0.0)
# Episode %d: PDE Error: %f (70, 0.0)
# Episode %d: PDE Error: %f (71, 0.0)
# Episode %d: PDE Error: %f (72, 0.0)
# Episode %d: PDE Error: %f (73, 0.0)
# Episode %d: PDE Error: %f (74, 0.0)
# Episode %d: PDE Error: %f (75, 0.0)
# Episode %d: PDE Error: %f (76, 0.0)
# Episode %d: PDE Error: %f (77, 0.0)
# Episode %d: PDE Error: %f (78, 0.0)
# Episode %d: PDE Error: %f (79, 0.0)
# Episode %d: PDE Error: %f (80, 0.0)
# Episode %d: PDE Error: %f (81, 0.0)
# Episode %d: PDE Error: %f (82, 0.0)
# Episode %d: PDE Error: %f (83, 0.0)
# Episode %d: PDE Error: %f (84, 0.0)
# Episode %d: PDE Error: %f (85, 0.0)
# Episode %d: PDE Error: %f (86, 0.0)
# Episode %d: PDE Error: %f (87, 0.0)
# Episode %d: PDE Error: %f (88, 0.0)
# Episode %d: PDE Error: %f (89, 0.0)
# Episode %d: PDE Error: %f (90, 0.0)
# Episode %d: PDE Error: %f (91, 0.0)
# Episode %d: PDE Error: %f (92, 0.0)
# Episode %d: PDE Error: %f (93, 0.0)
# Episode %d: PDE Error: %f (94, 0.0)
# Episode %d: PDE Error: %f (95, 0.0)
# Episode %d: PDE Error: %f (96, 0.0)
# Episode %d: PDE Error: %f (97, 0.0)
# Episode %d: PDE Error: %f (98, 0.0)
# Episode %d: PDE Error: %f (99, 0.0)
# Episode %d: PDE Error: %f (100, 0.0)
# Episode %d: PDE Error: %f (101, 0.0)
# Episode %d: PDE Error: %f (102, 0.0)
# Episode %d: PDE Error: %f (103, 0.0)
# Episode %d: PDE Error: %f (104, 0.0)
# Episode %d: PDE Error: %f (105, 0.0)
# Episode %d: PDE Error: %f (106, 0.0)
# Episode %d: PDE Error: %f (107, 0.0)
# Episode %d: PDE Error: %f (108, 0.0)
# Episode %d: PDE Error: %f (109, 0.0)
# Episode %d: PDE Error: %f (110, 0.0)
# Episode %d: PDE Error: %f (111, 0.0)
# Episode %d: PDE Error: %f (112, 0.0)
# Episode %d: PDE Error: %f (113, 0.0)
# Episode %d: PDE Error: %f (114, 0.0)
# Episode %d: PDE Error: %f (115, 0.0)
# Episode %d: PDE Error: %f (116, 0.0)
# Episode %d: PDE Error: %f (117, 0.0)
# Episode %d: PDE Error: %f (118, 0.0)
# Episode %d: PDE Error: %f (119, 0.0)
# Episode %d: PDE Error: %f (120, 0.0)
# Episode %d: PDE Error: %f (121, 0.0)
# Episode %d: PDE Error: %f (122, 0.0)
# Episode %d: PDE Error: %f (123, 0.0)
# Episode %d: PDE Error: %f (124, 0.0)
# Episode %d: PDE Error: %f (125, 0.0)
# Episode %d: PDE Error: %f (126, 0.0)
# Episode %d: PDE Error: %f (127, 0.0)
# Episode %d: PDE Error: %f (128, 0.0)
# Episode %d: PDE Error: %f (129, 0.0)
# Episode %d: PDE Error: %f (130, 0.0)
# Episode %d: PDE Error: %f (131, 0.0)
# Episode %d: PDE Error: %f (132, 0.0)
# Episode %d: PDE Error: %f (133, 0.0)
# Episode %d: PDE Error: %f (134, 0.0)
# Episode %d: PDE Error: %f (135, 0.0)
# Episode %d: PDE Error: %f (136, 0.0)
# Episode %d: PDE Error: %f (137, 0.0)
# Episode %d: PDE Error: %f (138, 0.0)
# Episode %d: PDE Error: %f (139, 0.0)
# Episode %d: PDE Error: %f (140, 0.0)
# Episode %d: PDE Error: %f (141, 0.0)
# Episode %d: PDE Error: %f (142, 0.0)
# Episode %d: PDE Error: %f (143, 0.0)
# Episode %d: PDE Error: %f (144, 0.0)
# Episode %d: PDE Error: %f (145, 0.0)
# Episode %d: PDE Error: %f (146, 0.0)
# Episode %d: PDE Error: %f (147, 0.0)
# Episode %d: PDE Error: %f (148, 0.0)
# Episode %d: PDE Error: %f (149, 0.0)
# Episode %d: PDE Error: %f (150, 0.0)
# Episode %d: PDE Error: %f (151, 0.0)
# Episode %d: PDE Error: %f (152, 0.0)
# Episode %d: PDE Error: %f (153, 0.0)
# Episode %d: PDE Error: %f (154, 0.0)
# Episode %d: PDE Error: %f (155, 0.0)
# Episode %d: PDE Error: %f (156, 0.0)
# Episode %d: PDE Error: %f (157, 0.0)
# Episode %d: PDE Error: %f (158, 0.0)
# Episode %d: PDE Error: %f (159, 0.0)
# Episode %d: PDE Error: %f (160, 0.0)
# Episode %d: PDE Error: %f (161, 0.0)
# Episode %d: PDE Error: %f (162, 0.0)
# Episode %d: PDE Error: %f (163, 0.0)
# Episode %d: PDE Error: %f (164, 0.0)
# Episode %d: PDE Error: %f (165, 0.0)
# Episode %d: PDE Error: %f (166, 0.0)
# Episode %d: PDE Error: %f (167, 0.0)
# Episode %d: PDE Error: %f (168, 0.0)
# Episode %d: PDE Error: %f (169, 0.0)
# Episode %d: PDE Error: %f (170, 0.0)
# Episode %d: PDE Error: %f (171, 0.0)
# Episode %d: PDE Error: %f (172, 0.0)
# Episode %d: PDE Error: %f (173, 0.0)
# Episode %d: PDE Error: %f (174, 0.0)
# Episode %d: PDE Error: %f (175, 0.0)
# Episode %d: PDE Error: %f (176, 0.0)
# Episode %d: PDE Error: %f (177, 0.0)
# Episode %d: PDE Error: %f (178, 0.0)
# Episode %d: PDE Error: %f (179, 0.0)
# Episode %d: PDE Error: %f (180, 0.0)
# Episode %d: PDE Error: %f (181, 0.0)
# Episode %d: PDE Error: %f (182, 0.0)
# Episode %d: PDE Error: %f (183, 0.0)
# Episode %d: PDE Error: %f (184, 0.0)
# Episode %d: PDE Error: %f (185, 0.0)
# Episode %d: PDE Error: %f (186, 0.0)
# Episode %d: PDE Error: %f (187, 0.0)
# Episode %d: PDE Error: %f (188, 0.0)
# Episode %d: PDE Error: %f (189, 0.0)
# Episode %d: PDE Error: %f (190, 0.0)
# Episode %d: PDE Error: %f (191, 0.0)
# Episode %d: PDE Error: %f (192, 0.0)
# Episode %d: PDE Error: %f (193, 0.0)
# Episode %d: PDE Error: %f (194, 0.0)
# Episode %d: PDE Error: %f (195, 0.0)
# Episode %d: PDE Error: %f (196, 0.0)
# Episode %d: PDE Error: %f (197, 0.0)
# Episode %d: PDE Error: %f (198, 0.0)
# Episode %d: PDE Error: %f (199, 0.0)
# Episode %d: PDE Error: %f (200, 0.0)
# Episode %d: PDE Error: %f (201, 0.0)
# Episode %d: PDE Error: %f (202, 0.0)
# Episode %d: PDE Error: %f (203, 0.0)
# Episode %d: PDE Error: %f (204, 0.0)
# Episode %d: PDE Error: %f (205, 0.0)
# Episode %d: PDE Error: %f (206, 0.0)
# Episode %d: PDE Error: %f (207, 0.0)
# Episode %d: PDE Error: %f (208, 0.0)
# Episode %d: PDE Error: %f (209, 0.0)
# Episode %d: PDE Error: %f (210, 0.0)
# Episode %d: PDE Error: %f (211, 0.0)
# Episode %d: PDE Error: %f (212, 0.0)
# Episode %d: PDE Error: %f (213, 0.0)
# Episode %d: PDE Error: %f (214, 0.0)
# Episode %d: PDE Error: %f (215, 0.0)
# Episode %d: PDE Error: %f (216, 0.0)
# Episode %d: PDE Error: %f (217, 0.0)
# Episode %d: PDE Error: %f (218, 0.0)
# Episode %d: PDE Error: %f (219, 0.0)
# Episode %d: PDE Error: %f (220, 0.0)
# Episode %d: PDE Error: %f (221, 0.0)
# Episode %d: PDE Error: %f (222, 0.0)
# Episode %d: PDE Error: %f (223, 0.0)
# Episode %d: PDE Error: %f (224, 0.0)
# Episode %d: PDE Error: %f (225, 0.0)
# Episode %d: PDE Error: %f (226, 0.0)
# Episode %d: PDE Error: %f (227, 0.0)
# Episode %d: PDE Error: %f (228, 0.0)
# Episode %d: PDE Error: %f (229, 0.0)
# Episode %d: PDE Error: %f (230, 0.0)
# Episode %d: PDE Error: %f (231, 0.0)
# Episode %d: PDE Error: %f (232, 0.0)
# Episode %d: PDE Error: %f (233, 0.0)
# Episode %d: PDE Error: %f (234, 0.0)
# Episode %d: PDE Error: %f (235, 0.0)
# Episode %d: PDE Error: %f (236, 0.0)
# Episode %d: PDE Error: %f (237, 0.0)
# Episode %d: PDE Error: %f (238, 0.0)
# Episode %d: PDE Error: %f (239, 0.0)
# Episode %d: PDE Error: %f (240, 0.0)
# Episode %d: PDE Error: %f (241, 0.0)
# Episode %d: PDE Error: %f (242, 0.0)
# Episode %d: PDE Error: %f (243, 0.0)
# Episode %d: PDE Error: %f (244, 0.0)
# Episode %d: PDE Error: %f (245, 0.0)
# Episode %d: PDE Error: %f (246, 0.0)
# Episode %d: PDE Error: %f (247, 0.0)
# Episode %d: PDE Error: %f (248, 0.0)
# Episode %d: PDE Error: %f (249, 0.0)
# Episode %d: PDE Error: %f (250, 0.0)
# Episode %d: PDE Error: %f (251, 0.0)
# Episode %d: PDE Error: %f (252, 0.0)
# Episode %d: PDE Error: %f (253, 0.0)
# Episode %d: PDE Error: %f (254, 0.0)
# Episode %d: PDE Error: %f (255, 0.0)
# Episode %d: PDE Error: %f (256, 0.0)
# Episode %d: PDE Error: %f (257, 0.0)
# Episode %d: PDE Error: %f (258, 0.0)
# Episode %d: PDE Error: %f (259, 0.0)
# Episode %d: PDE Error: %f (260, 0.0)
# Episode %d: PDE Error: %f (261, 0.0)
# Episode %d: PDE Error: %f (262, 0.0)
# Episode %d: PDE Error: %f (263, 0.0)
# Episode %d: PDE Error: %f (264, 0.0)
# Episode %d: PDE Error: %f (265, 0.0)
# Episode %d: PDE Error: %f (266, 0.0)
# Episode %d: PDE Error: %f (267, 0.0)
# Episode %d: PDE Error: %f (268, 0.0)
# Episode %d: PDE Error: %f (269, 0.0)
# Episode %d: PDE Error: %f (270, 0.0)
# Episode %d: PDE Error: %f (271, 0.0)
# Episode %d: PDE Error: %f (272, 0.0)
# Episode %d: PDE Error: %f (273, 0.0)
# Episode %d: PDE Error: %f (274, 0.0)
# Episode %d: PDE Error: %f (275, 0.0)
# Episode %d: PDE Error: %f (276, 0.0)
# Episode %d: PDE Error: %f (277, 0.0)
# Episode %d: PDE Error: %f (278, 0.0)
# Episode %d: PDE Error: %f (279, 0.0)
# Episode %d: PDE Error: %f (280, 0.0)
# Episode %d: PDE Error: %f (281, 0.0)
# Episode %d: PDE Error: %f (282, 0.0)
# Episode %d: PDE Error: %f (283, 0.0)
# Episode %d: PDE Error: %f (284, 0.0)
# Episode %d: PDE Error: %f (285, 0.0)
# Episode %d: PDE Error: %f (286, 0.0)
# Episode %d: PDE Error: %f (287, 0.0)
# Episode %d: PDE Error: %f (288, 0.0)
# Episode %d: PDE Error: %f (289, 0.0)
# Episode %d: PDE Error: %f (290, 0.0)
# Episode %d: PDE Error: %f (291, 0.0)
# Episode %d: PDE Error: %f (292, 0.0)
# Episode %d: PDE Error: %f (293, 0.0)
# Episode %d: PDE Error: %f (294, 0.0)
# Episode %d: PDE Error: %f (295, 0.0)
# Episode %d: PDE Error: %f (296, 0.0)
# Episode %d: PDE Error: %f (297, 0.0)
# Episode %d: PDE Error: %f (298, 0.0)
# Episode %d: PDE Error: %f (299, 0.0)
# Episode %d: PDE Error: %f (300, 0.0)
# Episode %d: PDE Error: %f (301, 0.0)
# Episode %d: PDE Error: %f (302, 0.0)
# Episode %d: PDE Error: %f (303, 0.0)
# Episode %d: PDE Error: %f (304, 0.0)
# Episode %d: PDE Error: %f (305, 0.0)
# Episode %d: PDE Error: %f (306, 0.0)
# Episode %d: PDE Error: %f (307, 0.0)
# Episode %d: PDE Error: %f (308, 0.0)
# Episode %d: PDE Error: %f (309, 0.0)
# Episode %d: PDE Error: %f (310, 0.0)
# Episode %d: PDE Error: %f (311, 0.0)
# Episode %d: PDE Error: %f (312, 0.0)
# Episode %d: PDE Error: %f (313, 0.0)
# Episode %d: PDE Error: %f (314, 0.0)
# Episode %d: PDE Error: %f (315, 0.0)
# Episode %d: PDE Error: %f (316, 0.0)
# Episode %d: PDE Error: %f (317, 0.0)
# Episode %d: PDE Error: %f (318, 0.0)
# Episode %d: PDE Error: %f (319, 0.0)
# Episode %d: PDE Error: %f (320, 0.0)
# Episode %d: PDE Error: %f (321, 0.0)
# Episode %d: PDE Error: %f (322, 0.0)
# Episode %d: PDE Error: %f (323, 0.0)
# Episode %d: PDE Error: %f (324, 0.0)
# Episode %d: PDE Error: %f (325, 0.0)
# Episode %d: PDE Error: %f (326, 0.0)
# Episode %d: PDE Error: %f (327, 0.0)
# Episode %d: PDE Error: %f (328, 0.0)
# Episode %d: PDE Error: %f (329, 0.0)
# Episode %d: PDE Error: %f (330, 0.0)
# Episode %d: PDE Error: %f (331, 0.0)
# Episode %d: PDE Error: %f (332, 0.0)
# Episode %d: PDE Error: %f (333, 0.0)
# Episode %d: PDE Error: %f (334, 0.0)
# Episode %d: PDE Error: %f (335, 0.0)
# Episode %d: PDE Error: %f (336, 0.0)
# Episode %d: PDE Error: %f (337, 0.0)
# Episode %d: PDE Error: %f (338, 0.0)
# Episode %d: PDE Error: %f (339, 0.0)
# Episode %d: PDE Error: %f (340, 0.0)
# Episode %d: PDE Error: %f (341, 0.0)
# Episode %d: PDE Error: %f (342, 0.0)
# Episode %d: PDE Error: %f (343, 0.0)
# Episode %d: PDE Error: %f (344, 0.0)
# Episode %d: PDE Error: %f (345, 0.0)
# Episode %d: PDE Error: %f (346, 0.0)
# Episode %d: PDE Error: %f (347, 0.0)
# Episode %d: PDE Error: %f (348, 0.0)
# Episode %d: PDE Error: %f (349, 0.0)
# Episode %d: PDE Error: %f (350, 0.0)
# Episode %d: PDE Error: %f (351, 0.0)
# Episode %d: PDE Error: %f (352, 0.0)
# Episode %d: PDE Error: %f (353, 0.0)
# Episode %d: PDE Error: %f (354, 0.0)
# Episode %d: PDE Error: %f (355, 0.0)
# Episode %d: PDE Error: %f (356, 0.0)
# Episode %d: PDE Error: %f (357, 0.0)
# Episode %d: PDE Error: %f (358, 0.0)
# Episode %d: PDE Error: %f (359, 0.0)
# Episode %d: PDE Error: %f (360, 0.0)
# Episode %d: PDE Error: %f (361, 0.0)
# Episode %d: PDE Error: %f (362, 0.0)
# Episode %d: PDE Error: %f (363, 0.0)
# Episode %d: PDE Error: %f (364, 0.0)
# Episode %d: PDE Error: %f (365, 0.0)
# Episode %d: PDE Error: %f (366, 0.0)
# Episode %d: PDE Error: %f (367, 0.0)
# Episode %d: PDE Error: %f (368, 0.0)
# Episode %d: PDE Error: %f (369, 0.0)
# Episode %d: PDE Error: %f (370, 0.0)
# Episode %d: PDE Error: %f (371, 0.0)
# Episode %d: PDE Error: %f (372, 0.0)
# Episode %d: PDE Error: %f (373, 0.0)
# Episode %d: PDE Error: %f (374, 0.0)
# Episode %d: PDE Error: %f (375, 0.0)
# Episode %d: PDE Error: %f (376, 0.0)
# Episode %d: PDE Error: %f (377, 0.0)
# Episode %d: PDE Error: %f (378, 0.0)
# Episode %d: PDE Error: %f (379, 0.0)
# Episode %d: PDE Error: %f (380, 0.0)
# Episode %d: PDE Error: %f (381, 0.0)
# Episode %d: PDE Error: %f (382, 0.0)
# Episode %d: PDE Error: %f (383, 0.0)
# Episode %d: PDE Error: %f (384, 0.0)
# Episode %d: PDE Error: %f (385, 0.0)
# Episode %d: PDE Error: %f (386, 0.0)
# Episode %d: PDE Error: %f (387, 0.0)
# Episode %d: PDE Error: %f (388, 0.0)
# Episode %d: PDE Error: %f (389, 0.0)
# Episode %d: PDE Error: %f (390, 0.0)
# Episode %d: PDE Error: %f (391, 0.0)
# Episode %d: PDE Error: %f (392, 0.0)
# Episode %d: PDE Error: %f (393, 0.0)
# Episode %d: PDE Error: %f (394, 0.0)
# Episode %d: PDE Error: %f (395, 0.0)
# Episode %d: PDE Error: %f (396, 0.0)
# Episode %d: PDE Error: %f (397, 0.0)
# Episode %d: PDE Error: %f (398, 0.0)
# Episode %d: PDE Error: %f (399, 0.0)
# Episode %d: PDE Error: %f (400, 0.0)
# Episode %d: PDE Error: %f (401, 0.0)
# Episode %d: PDE Error: %f (402, 0.0)
# Episode %d: PDE Error: %f (403, 0.0)
# Episode %d: PDE Error: %f (404, 0.0)
# Episode %d: PDE Error: %f (405, 0.0)
# Episode %d: PDE Error: %f (406, 0.0)
# Episode %d: PDE Error: %f (407, 0.0)
# Episode %d: PDE Error: %f (408, 0.0)
# Episode %d: PDE Error: %f (409, 0.0)
# Episode %d: PDE Error: %f (410, 0.0)
# Episode %d: PDE Error: %f (411, 0.0)
# Episode %d: PDE Error: %f (412, 0.0)
# Episode %d: PDE Error: %f (413, 0.0)
# Episode %d: PDE Error: %f (414, 0.0)
# Episode %d: PDE Error: %f (415, 0.0)
# Episode %d: PDE Error: %f (416, 0.0)
# Episode %d: PDE Error: %f (417, 0.0)
# Episode %d: PDE Error: %f (418, 0.0)
# Episode %d: PDE Error: %f (419, 0.0)
# Episode %d: PDE Error: %f (420, 0.0)
# Episode %d: PDE Error: %f (421, 0.0)
# Episode %d: PDE Error: %f (422, 0.0)
# Episode %d: PDE Error: %f (423, 0.0)
# Episode %d: PDE Error: %f (424, 0.0)
# Episode %d: PDE Error: %f (425, 0.0)
# Episode %d: PDE Error: %f (426, 0.0)
# Episode %d: PDE Error: %f (427, 0.0)
# Episode %d: PDE Error: %f (428, 0.0)
# Episode %d: PDE Error: %f (429, 0.0)
# Episode %d: PDE Error: %f (430, 0.0)
# Episode %d: PDE Error: %f (431, 0.0)
# Episode %d: PDE Error: %f (432, 0.0)
# Episode %d: PDE Error: %f (433, 0.0)
# Episode %d: PDE Error: %f (434, 0.0)
# Episode %d: PDE Error: %f (435, 0.0)
# Episode %d: PDE Error: %f (436, 0.0)
# Episode %d: PDE Error: %f (437, 0.0)
# Episode %d: PDE Error: %f (438, 0.0)
# Episode %d: PDE Error: %f (439, 0.0)
# Episode %d: PDE Error: %f (440, 0.0)
# Episode %d: PDE Error: %f (441, 0.0)
# Episode %d: PDE Error: %f (442, 0.0)
# Episode %d: PDE Error: %f (443, 0.0)
# Episode %d: PDE Error: %f (444, 0.0)
# Episode %d: PDE Error: %f (445, 0.0)
# Episode %d: PDE Error: %f (446, 0.0)
# Episode %d: PDE Error: %f (447, 0.0)
# Episode %d: PDE Error: %f (448, 0.0)
# Episode %d: PDE Error: %f (449, 0.0)
# Episode %d: PDE Error: %f (450, 0.0)
# Episode %d: PDE Error: %f (451, 0.0)
# Episode %d: PDE Error: %f (452, 0.0)
# Episode %d: PDE Error: %f (453, 0.0)
# Episode %d: PDE Error: %f (454, 0.0)
# Episode %d: PDE Error: %f (455, 0.0)
# Episode %d: PDE Error: %f (456, 0.0)
# Episode %d: PDE Error: %f (457, 0.0)
# Episode %d: PDE Error: %f (458, 0.0)
# Episode %d: PDE Error: %f (459, 0.0)
# Episode %d: PDE Error: %f (460, 0.0)
# Episode %d: PDE Error: %f (461, 0.0)
# Episode %d: PDE Error: %f (462, 0.0)
# Episode %d: PDE Error: %f (463, 0.0)
# Episode %d: PDE Error: %f (464, 0.0)
# Episode %d: PDE Error: %f (465, 0.0)
# Episode %d: PDE Error: %f (466, 0.0)
# Episode %d: PDE Error: %f (467, 0.0)
# Episode %d: PDE Error: %f (468, 0.0)
# Episode %d: PDE Error: %f (469, 0.0)
# Episode %d: PDE Error: %f (470, 0.0)
# Episode %d: PDE Error: %f (471, 0.0)
# Episode %d: PDE Error: %f (472, 0.0)
# Episode %d: PDE Error: %f (473, 0.0)
# Episode %d: PDE Error: %f (474, 0.0)
# Episode %d: PDE Error: %f (475, 0.0)
# Episode %d: PDE Error: %f (476, 0.0)
# Episode %d: PDE Error: %f (477, 0.0)
# Episode %d: PDE Error: %f (478, 0.0)
# Episode %d: PDE Error: %f (479, 0.0)
# Episode %d: PDE Error: %f (480, 0.0)
# Episode %d: PDE Error: %f (481, 0.0)
# Episode %d: PDE Error: %f (482, 0.0)
# Episode %d: PDE Error: %f (483, 0.0)
# Episode %d: PDE Error: %f (484, 0.0)
# Episode %d: PDE Error: %f (485, 0.0)
# Episode %d: PDE Error: %f (486, 0.0)
# Episode %d: PDE Error: %f (487, 0.0)
# Episode %d: PDE Error: %f (488, 0.0)
# Episode %d: PDE Error: %f (489, 0.0)
# Episode %d: PDE Error: %f (490, 0.0)
# Episode %d: PDE Error: %f (491, 0.0)
# Episode %d: PDE Error: %f (492, 0.0)
# Episode %d: PDE Error: %f (493, 0.0)
# Episode %d: PDE Error: %f (494, 0.0)
# Episode %d: PDE Error: %f (495, 0.0)
# Episode %d: PDE Error: %f (496, 0.0)
# Episode %d: PDE Error: %f (497, 0.0)
# Episode %d: PDE Error: %f (498, 0.0)
# Episode %d: PDE Error: %f (499, 0.0)
# Episode %d: PDE Error: %f (500, 0.0)
# Episode %d: PDE Error: %f (501, 0.0)
# Episode %d: PDE Error: %f (502, 0.0)
# Episode %d: PDE Error: %f (503, 0.0)
# Episode %d: PDE Error: %f (504, 0.0)
# Episode %d: PDE Error: %f (505, 0.0)
# Episode %d: PDE Error: %f (506, 0.0)
# Episode %d: PDE Error: %f (507, 0.0)
# Episode %d: PDE Error: %f (508, 0.0)
# Episode %d: PDE Error: %f (509, 0.0)
# Episode %d: PDE Error: %f (510, 0.0)
# Episode %d: PDE Error: %f (511, 0.0)
# Episode %d: PDE Error: %f (512, 0.0)
# Episode %d: PDE Error: %f (513, 0.0)
# Episode %d: PDE Error: %f (514, 0.0)
# Episode %d: PDE Error: %f (515, 0.0)
# Episode %d: PDE Error: %f (516, 0.0)
# Episode %d: PDE Error: %f (517, 0.0)
# Episode %d: PDE Error: %f (518, 0.0)
# Episode %d: PDE Error: %f (519, 0.0)
# Episode %d: PDE Error: %f (520, 0.0)
# Episode %d: PDE Error: %f (521, 0.0)
# Episode %d: PDE Error: %f (522, 0.0)
# Episode %d: PDE Error: %f (523, 0.0)
# Episode %d: PDE Error: %f (524, 0.0)
# Episode %d: PDE Error: %f (525, 0.0)
# Episode %d: PDE Error: %f (526, 0.0)
# Episode %d: PDE Error: %f (527, 0.0)
# Episode %d: PDE Error: %f (528, 0.0)
# Episode %d: PDE Error: %f (529, 0.0)
# Episode %d: PDE Error: %f (530, 0.0)
# Episode %d: PDE Error: %f (531, 0.0)
# Episode %d: PDE Error: %f (532, 0.0)
# Episode %d: PDE Error: %f (533, 0.0)
# Episode %d: PDE Error: %f (534, 0.0)
# Episode %d: PDE Error: %f (535, 0.0)
# Episode %d: PDE Error: %f (536, 0.0)
# Episode %d: PDE Error: %f (537, 0.0)
# Episode %d: PDE Error: %f (538, 0.0)
# Episode %d: PDE Error: %f (539, 0.0)
# Episode %d: PDE Error: %f (540, 0.0)
# Episode %d: PDE Error: %f (541, 0.0)
# Episode %d: PDE Error: %f (542, 0.0)
# Episode %d: PDE Error: %f (543, 0.0)
# Episode %d: PDE Error: %f (544, 0.0)
# Episode %d: PDE Error: %f (545, 0.0)
# Episode %d: PDE Error: %f (546, 0.0)
# Episode %d: PDE Error: %f (547, 0.0)
# Episode %d: PDE Error: %f (548, 0.0)
# Episode %d: PDE Error: %f (549, 0.0)
# Episode %d: PDE Error: %f (550, 0.0)
# Episode %d: PDE Error: %f (551, 0.0)
# Episode %d: PDE Error: %f (552, 0.0)
# Episode %d: PDE Error: %f (553, 0.0)
# Episode %d: PDE Error: %f (554, 0.0)
# Episode %d: PDE Error: %f (555, 0.0)
# Episode %d: PDE Error: %f (556, 0.0)
# Episode %d: PDE Error: %f (557, 0.0)
# Episode %d: PDE Error: %f (558, 0.0)
# Episode %d: PDE Error: %f (559, 0.0)
# Episode %d: PDE Error: %f (560, 0.0)
# Episode %d: PDE Error: %f (561, 0.0)
# Episode %d: PDE Error: %f (562, 0.0)
# Episode %d: PDE Error: %f (563, 0.0)
# Episode %d: PDE Error: %f (564, 0.0)
# Episode %d: PDE Error: %f (565, 0.0)
# Episode %d: PDE Error: %f (566, 0.0)
# Episode %d: PDE Error: %f (567, 0.0)
# Episode %d: PDE Error: %f (568, 0.0)
# Episode %d: PDE Error: %f (569, 0.0)
# Episode %d: PDE Error: %f (570, 0.0)
# Episode %d: PDE Error: %f (571, 0.0)
# Episode %d: PDE Error: %f (572, 0.0)
# Episode %d: PDE Error: %f (573, 0.0)
# Episode %d: PDE Error: %f (574, 0.0)
# Episode %d: PDE Error: %f (575, 0.0)
# Episode %d: PDE Error: %f (576, 0.0)
# Episode %d: PDE Error: %f (577, 0.0)
# Episode %d: PDE Error: %f (578, 0.0)
# Episode %d: PDE Error: %f (579, 0.0)
# Episode %d: PDE Error: %f (580, 0.0)
# Episode %d: PDE Error: %f (581, 0.0)
# Episode %d: PDE Error: %f (582, 0.0)
# Episode %d: PDE Error: %f (583, 0.0)
# Episode %d: PDE Error: %f (584, 0.0)
# Episode %d: PDE Error: %f (585, 0.0)
# Episode %d: PDE Error: %f (586, 0.0)
# Episode %d: PDE Error: %f (587, 0.0)
# Episode %d: PDE Error: %f (588, 0.0)
# Episode %d: PDE Error: %f (589, 0.0)
# Episode %d: PDE Error: %f (590, 0.0)
# Episode %d: PDE Error: %f (591, 0.0)
# Episode %d: PDE Error: %f (592, 0.0)
# Episode %d: PDE Error: %f (593, 0.0)
# Episode %d: PDE Error: %f (594, 0.0)
# Episode %d: PDE Error: %f (595, 0.0)
# Episode %d: PDE Error: %f (596, 0.0)
# Episode %d: PDE Error: %f (597, 0.0)
# Episode %d: PDE Error: %f (598, 0.0)
# Episode %d: PDE Error: %f (599, 0.0)
# Episode %d: PDE Error: %f (600, 0.0)
# Episode %d: PDE Error: %f (601, 0.0)
# Episode %d: PDE Error: %f (602, 0.0)
# Episode %d: PDE Error: %f (603, 0.0)
# Episode %d: PDE Error: %f (604, 0.0)
# Episode %d: PDE Error: %f (605, 0.0)
# Episode %d: PDE Error: %f (606, 0.0)
# Episode %d: PDE Error: %f (607, 0.0)
# Episode %d: PDE Error: %f (608, 0.0)
# Episode %d: PDE Error: %f (609, 0.0)
# Episode %d: PDE Error: %f (610, 0.0)
# Episode %d: PDE Error: %f (611, 0.0)
# Episode %d: PDE Error: %f (612, 0.0)
# Episode %d: PDE Error: %f (613, 0.0)
# Episode %d: PDE Error: %f (614, 0.0)
# Episode %d: PDE Error: %f (615, 0.0)
# Episode %d: PDE Error: %f (616, 0.0)
# Episode %d: PDE Error: %f (617, 0.0)
# Episode %d: PDE Error: %f (618, 0.0)
# Episode %d: PDE Error: %f (619, 0.0)
# Episode %d: PDE Error: %f (620, 0.0)
# Episode %d: PDE Error: %f (621, 0.0)
# Episode %d: PDE Error: %f (622, 0.0)
# Episode %d: PDE Error: %f (623, 0.0)
# Episode %d: PDE Error: %f (624, 0.0)
# Episode %d: PDE Error: %f (625, 0.0)
# Episode %d: PDE Error: %f (626, 0.0)
# Episode %d: PDE Error: %f (627, 0.0)
# Episode %d: PDE Error: %f (628, 0.0)
# Episode %d: PDE Error: %f (629, 0.0)
# Episode %d: PDE Error: %f (630, 0.0)
# Episode %d: PDE Error: %f (631, 0.0)
# Episode %d: PDE Error: %f (632, 0.0)
# Episode %d: PDE Error: %f (633, 0.0)
# Episode %d: PDE Error: %f (634, 0.0)
# Episode %d: PDE Error: %f (635, 0.0)
# Episode %d: PDE Error: %f (636, 0.0)
# Episode %d: PDE Error: %f (637, 0.0)
# Episode %d: PDE Error: %f (638, 0.0)
# Episode %d: PDE Error: %f (639, 0.0)
# Episode %d: PDE Error: %f (640, 0.0)
# Episode %d: PDE Error: %f (641, 0.0)
# Episode %d: PDE Error: %f (642, 0.0)
# Episode %d: PDE Error: %f (643, 0.0)
# Episode %d: PDE Error: %f (644, 0.0)
# Episode %d: PDE Error: %f (645, 0.0)
# Episode %d: PDE Error: %f (646, 0.0)
# Episode %d: PDE Error: %f (647, 0.0)
# Episode %d: PDE Error: %f (648, 0.0)
# Episode %d: PDE Error: %f (649, 0.0)
# Episode %d: PDE Error: %f (650, 0.0)
# Episode %d: PDE Error: %f (651, 0.0)
# Episode %d: PDE Error: %f (652, 0.0)
# Episode %d: PDE Error: %f (653, 0.0)
# Episode %d: PDE Error: %f (654, 0.0)
# Episode %d: PDE Error: %f (655, 0.0)
# Episode %d: PDE Error: %f (656, 0.0)
# Episode %d: PDE Error: %f (657, 0.0)
# Episode %d: PDE Error: %f (658, 0.0)
# Episode %d: PDE Error: %f (659, 0.0)
# Episode %d: PDE Error: %f (660, 0.0)
# Episode %d: PDE Error: %f (661, 0.0)
# Episode %d: PDE Error: %f (662, 0.0)
# Episode %d: PDE Error: %f (663, 0.0)
# Episode %d: PDE Error: %f (664, 0.0)
# Episode %d: PDE Error: %f (665, 0.0)
# Episode %d: PDE Error: %f (666, 0.0)
# Episode %d: PDE Error: %f (667, 0.0)
# Episode %d: PDE Error: %f (668, 0.0)
# Episode %d: PDE Error: %f (669, 0.0)
# Episode %d: PDE Error: %f (670, 0.0)
# Episode %d: PDE Error: %f (671, 0.0)
# Episode %d: PDE Error: %f (672, 0.0)
# Episode %d: PDE Error: %f (673, 0.0)
# Episode %d: PDE Error: %f (674, 0.0)
# Episode %d: PDE Error: %f (675, 0.0)
# Episode %d: PDE Error: %f (676, 0.0)
# Episode %d: PDE Error: %f (677, 0.0)
# Episode %d: PDE Error: %f (678, 0.0)
# Episode %d: PDE Error: %f (679, 0.0)
# Episode %d: PDE Error: %f (680, 0.0)
# Episode %d: PDE Error: %f (681, 0.0)
# Episode %d: PDE Error: %f (682, 0.0)
# Episode %d: PDE Error: %f (683, 0.0)
# Episode %d: PDE Error: %f (684, 0.0)
# Episode %d: PDE Error: %f (685, 0.0)
# Episode %d: PDE Error: %f (686, 0.0)
# Episode %d: PDE Error: %f (687, 0.0)
# Episode %d: PDE Error: %f (688, 0.0)
# Episode %d: PDE Error: %f (689, 0.0)
# Episode %d: PDE Error: %f (690, 0.0)
# Episode %d: PDE Error: %f (691, 0.0)
# Episode %d: PDE Error: %f (692, 0.0)
# Episode %d: PDE Error: %f (693, 0.0)
# Episode %d: PDE Error: %f (694, 0.0)
# Episode %d: PDE Error: %f (695, 0.0)
# Episode %d: PDE Error: %f (696, 0.0)
# Episode %d: PDE Error: %f (697, 0.0)
# Episode %d: PDE Error: %f (698, 0.0)
# Episode %d: PDE Error: %f (699, 0.0)
# Episode %d: PDE Error: %f (700, 0.0)
# Episode %d: PDE Error: %f (701, 0.0)
# Episode %d: PDE Error: %f (702, 0.0)
# Episode %d: PDE Error: %f (703, 0.0)
# Episode %d: PDE Error: %f (704, 0.0)
# Episode %d: PDE Error: %f (705, 0.0)
# Episode %d: PDE Error: %f (706, 0.0)
# Episode %d: PDE Error: %f (707, 0.0)
# Episode %d: PDE Error: %f (708, 0.0)
# Episode %d: PDE Error: %f (709, 0.0)
# Episode %d: PDE Error: %f (710, 0.0)
# Episode %d: PDE Error: %f (711, 0.0)
# Episode %d: PDE Error: %f (712, 0.0)
# Episode %d: PDE Error: %f (713, 0.0)
# Episode %d: PDE Error: %f (714, 0.0)
# Episode %d: PDE Error: %f (715, 0.0)
# Episode %d: PDE Error: %f (716, 0.0)
# Episode %d: PDE Error: %f (717, 0.0)
# Episode %d: PDE Error: %f (718, 0.0)
# Episode %d: PDE Error: %f (719, 0.0)
# Episode %d: PDE Error: %f (720, 0.0)
# Episode %d: PDE Error: %f (721, 0.0)
# Episode %d: PDE Error: %f (722, 0.0)
# Episode %d: PDE Error: %f (723, 0.0)
# Episode %d: PDE Error: %f (724, 0.0)
# Episode %d: PDE Error: %f (725, 0.0)
# Episode %d: PDE Error: %f (726, 0.0)
# Episode %d: PDE Error: %f (727, 0.0)
# Episode %d: PDE Error: %f (728, 0.0)
# Episode %d: PDE Error: %f (729, 0.0)
# Episode %d: PDE Error: %f (730, 0.0)
# Episode %d: PDE Error: %f (731, 0.0)
# Episode %d: PDE Error: %f (732, 0.0)
# Episode %d: PDE Error: %f (733, 0.0)
# Episode %d: PDE Error: %f (734, 0.0)
# Episode %d: PDE Error: %f (735, 0.0)
# Episode %d: PDE Error: %f (736, 0.0)
# Episode %d: PDE Error: %f (737, 0.0)
# Episode %d: PDE Error: %f (738, 0.0)
# Episode %d: PDE Error: %f (739, 0.0)
# Episode %d: PDE Error: %f (740, 0.0)
# Episode %d: PDE Error: %f (741, 0.0)
# Episode %d: PDE Error: %f (742, 0.0)
# Episode %d: PDE Error: %f (743, 0.0)
# Episode %d: PDE Error: %f (744, 0.0)
# Episode %d: PDE Error: %f (745, 0.0)
# Episode %d: PDE Error: %f (746, 0.0)
# Episode %d: PDE Error: %f (747, 0.0)
# Episode %d: PDE Error: %f (748, 0.0)
# Episode %d: PDE Error: %f (749, 0.0)
# Episode %d: PDE Error: %f (750, 0.0)
# Episode %d: PDE Error: %f (751, 0.0)
# Episode %d: PDE Error: %f (752, 0.0)
# Episode %d: PDE Error: %f (753, 0.0)
# Episode %d: PDE Error: %f (754, 0.0)
# Episode %d: PDE Error: %f (755, 0.0)
# Episode %d: PDE Error: %f (756, 0.0)
# Episode %d: PDE Error: %f (757, 0.0)
# Episode %d: PDE Error: %f (758, 0.0)
# Episode %d: PDE Error: %f (759, 0.0)
# Episode %d: PDE Error: %f (760, 0.0)
# Episode %d: PDE Error: %f (761, 0.0)
# Episode %d: PDE Error: %f (762, 0.0)
# Episode %d: PDE Error: %f (763, 0.0)
# Episode %d: PDE Error: %f (764, 0.0)
# Episode %d: PDE Error: %f (765, 0.0)
# Episode %d: PDE Error: %f (766, 0.0)
# Episode %d: PDE Error: %f (767, 0.0)
# Episode %d: PDE Error: %f (768, 0.0)
# Episode %d: PDE Error: %f (769, 0.0)
# Episode %d: PDE Error: %f (770, 0.0)
# Episode %d: PDE Error: %f (771, 0.0)
# Episode %d: PDE Error: %f (772, 0.0)
# Episode %d: PDE Error: %f (773, 0.0)
# Episode %d: PDE Error: %f (774, 0.0)
# Episode %d: PDE Error: %f (775, 0.0)
# Episode %d: PDE Error: %f (776, 0.0)
# Episode %d: PDE Error: %f (777, 0.0)
# Episode %d: PDE Error: %f (778, 0.0)
# Episode %d: PDE Error: %f (779, 0.0)
# Episode %d: PDE Error: %f (780, 0.0)
# Episode %d: PDE Error: %f (781, 0.0)
# Episode %d: PDE Error: %f (782, 0.0)
# Episode %d: PDE Error: %f (783, 0.0)
# Episode %d: PDE Error: %f (784, 0.0)
# Episode %d: PDE Error: %f (785, 0.0)
# Episode %d: PDE Error: %f (786, 0.0)
# Episode %d: PDE Error: %f (787, 0.0)
# Episode %d: PDE Error: %f (788, 0.0)
# Episode %d: PDE Error: %f (789, 0.0)
# Episode %d: PDE Error: %f (790, 0.0)
# Episode %d: PDE Error: %f (791, 0.0)
# Episode %d: PDE Error: %f (792, 0.0)
# Episode %d: PDE Error: %f (793, 0.0)
# Episode %d: PDE Error: %f (794, 0.0)
# Episode %d: PDE Error: %f (795, 0.0)
# Episode %d: PDE Error: %f (796, 0.0)
# Episode %d: PDE Error: %f (797, 0.0)
# Episode %d: PDE Error: %f (798, 0.0)
# Episode %d: PDE Error: %f (799, 0.0)
# Episode %d: PDE Error: %f (800, 0.0)
# Episode %d: PDE Error: %f (801, 0.0)
# Episode %d: PDE Error: %f (802, 0.0)
# Episode %d: PDE Error: %f (803, 0.0)
# Episode %d: PDE Error: %f (804, 0.0)
# Episode %d: PDE Error: %f (805, 0.0)
# Episode %d: PDE Error: %f (806, 0.0)
# Episode %d: PDE Error: %f (807, 0.0)
# Episode %d: PDE Error: %f (808, 0.0)
# Episode %d: PDE Error: %f (809, 0.0)
# Episode %d: PDE Error: %f (810, 0.0)
# Episode %d: PDE Error: %f (811, 0.0)
# Episode %d: PDE Error: %f (812, 0.0)
# Episode %d: PDE Error: %f (813, 0.0)
# Episode %d: PDE Error: %f (814, 0.0)
# Episode %d: PDE Error: %f (815, 0.0)
# Episode %d: PDE Error: %f (816, 0.0)
# Episode %d: PDE Error: %f (817, 0.0)
# Episode %d: PDE Error: %f (818, 0.0)
# Episode %d: PDE Error: %f (819, 0.0)
# Episode %d: PDE Error: %f (820, 0.0)
# Episode %d: PDE Error: %f (821, 0.0)
# Episode %d: PDE Error: %f (822, 0.0)
# Episode %d: PDE Error: %f (823, 0.0)
# Episode %d: PDE Error: %f (824, 0.0)
# Episode %d: PDE Error: %f (825, 0.0)
# Episode %d: PDE Error: %f (826, 0.0)
# Episode %d: PDE Error: %f (827, 0.0)
# Episode %d: PDE Error: %f (828, 0.0)
# Episode %d: PDE Error: %f (829, 0.0)
# Episode %d: PDE Error: %f (830, 0.0)
# Episode %d: PDE Error: %f (831, 0.0)
# Episode %d: PDE Error: %f (832, 0.0)
# Episode %d: PDE Error: %f (833, 0.0)
# Episode %d: PDE Error: %f (834, 0.0)
# Episode %d: PDE Error: %f (835, 0.0)
# Episode %d: PDE Error: %f (836, 0.0)
# Episode %d: PDE Error: %f (837, 0.0)
# Episode %d: PDE Error: %f (838, 0.0)
# Episode %d: PDE Error: %f (839, 0.0)
# Episode %d: PDE Error: %f (840, 0.0)
# Episode %d: PDE Error: %f (841, 0.0)
# Episode %d: PDE Error: %f (842, 0.0)
# Episode %d: PDE Error: %f (843, 0.0)
# Episode %d: PDE Error: %f (844, 0.0)
# Episode %d: PDE Error: %f (845, 0.0)
# Episode %d: PDE Error: %f (846, 0.0)
# Episode %d: PDE Error: %f (847, 0.0)
# Episode %d: PDE Error: %f (848, 0.0)
# Episode %d: PDE Error: %f (849, 0.0)
# Episode %d: PDE Error: %f (850, 0.0)
# Episode %d: PDE Error: %f (851, 0.0)
# Episode %d: PDE Error: %f (852, 0.0)
# Episode %d: PDE Error: %f (853, 0.0)
# Episode %d: PDE Error: %f (854, 0.0)
# Episode %d: PDE Error: %f (855, 0.0)
# Episode %d: PDE Error: %f (856, 0.0)
# Episode %d: PDE Error: %f (857, 0.0)
# Episode %d: PDE Error: %f (858, 0.0)
# Episode %d: PDE Error: %f (859, 0.0)
# Episode %d: PDE Error: %f (860, 0.0)
# Episode %d: PDE Error: %f (861, 0.0)
# Episode %d: PDE Error: %f (862, 0.0)
# Episode %d: PDE Error: %f (863, 0.0)
# Episode %d: PDE Error: %f (864, 0.0)
# Episode %d: PDE Error: %f (865, 0.0)
# Episode %d: PDE Error: %f (866, 0.0)
# Episode %d: PDE Error: %f (867, 0.0)
# Episode %d: PDE Error: %f (868, 0.0)
# Episode %d: PDE Error: %f (869, 0.0)
# Episode %d: PDE Error: %f (870, 0.0)
# Episode %d: PDE Error: %f (871, 0.0)
# Episode %d: PDE Error: %f (872, 0.0)
# Episode %d: PDE Error: %f (873, 0.0)
# Episode %d: PDE Error: %f (874, 0.0)
# Episode %d: PDE Error: %f (875, 0.0)
# Episode %d: PDE Error: %f (876, 0.0)
# Episode %d: PDE Error: %f (877, 0.0)
# Episode %d: PDE Error: %f (878, 0.0)
# Episode %d: PDE Error: %f (879, 0.0)
# Episode %d: PDE Error: %f (880, 0.0)
# Episode %d: PDE Error: %f (881, 0.0)
# Episode %d: PDE Error: %f (882, 0.0)
# Episode %d: PDE Error: %f (883, 0.0)
# Episode %d: PDE Error: %f (884, 0.0)
# Episode %d: PDE Error: %f (885, 0.0)
# Episode %d: PDE Error: %f (886, 0.0)
# Episode %d: PDE Error: %f (887, 0.0)
# Episode %d: PDE Error: %f (888, 0.0)
# Episode %d: PDE Error: %f (889, 0.0)
# Episode %d: PDE Error: %f (890, 0.0)
# Episode %d: PDE Error: %f (891, 0.0)
# Episode %d: PDE Error: %f (892, 0.0)
# Episode %d: PDE Error: %f (893, 0.0)
# Episode %d: PDE Error: %f (894, 0.0)
# Episode %d: PDE Error: %f (895, 0.0)
# Episode %d: PDE Error: %f (896, 0.0)
# Episode %d: PDE Error: %f (897, 0.0)
# Episode %d: PDE Error: %f (898, 0.0)
# Episode %d: PDE Error: %f (899, 0.0)
# Episode %d: PDE Error: %f (900, 0.0)
# Episode %d: PDE Error: %f (901, 0.0)
# Episode %d: PDE Error: %f (902, 0.0)
# Episode %d: PDE Error: %f (903, 0.0)
# Episode %d: PDE Error: %f (904, 0.0)
# Episode %d: PDE Error: %f (905, 0.0)
# Episode %d: PDE Error: %f (906, 0.0)
# Episode %d: PDE Error: %f (907, 0.0)
# Episode %d: PDE Error: %f (908, 0.0)
# Episode %d: PDE Error: %f (909, 0.0)
# Episode %d: PDE Error: %f (910, 0.0)
# Episode %d: PDE Error: %f (911, 0.0)
# Episode %d: PDE Error: %f (912, 0.0)
# Episode %d: PDE Error: %f (913, 0.0)
# Episode %d: PDE Error: %f (914, 0.0)
# Episode %d: PDE Error: %f (915, 0.0)
# Episode %d: PDE Error: %f (916, 0.0)
# Episode %d: PDE Error: %f (917, 0.0)
# Episode %d: PDE Error: %f (918, 0.0)
# Episode %d: PDE Error: %f (919, 0.0)
# Episode %d: PDE Error: %f (920, 0.0)
# Episode %d: PDE Error: %f (921, 0.0)
# Episode %d: PDE Error: %f (922, 0.0)
# Episode %d: PDE Error: %f (923, 0.0)
# Episode %d: PDE Error: %f (924, 0.0)
# Episode %d: PDE Error: %f (925, 0.0)
# Episode %d: PDE Error: %f (926, 0.0)
# Episode %d: PDE Error: %f (927, 0.0)
# Episode %d: PDE Error: %f (928, 0.0)
# Episode %d: PDE Error: %f (929, 0.0)
# Episode %d: PDE Error: %f (930, 0.0)
# Episode %d: PDE Error: %f (931, 0.0)
# Episode %d: PDE Error: %f (932, 0.0)
# Episode %d: PDE Error: %f (933, 0.0)
# Episode %d: PDE Error: %f (934, 0.0)
# Episode %d: PDE Error: %f (935, 0.0)
# Episode %d: PDE Error: %f (936, 0.0)
# Episode %d: PDE Error: %f (937, 0.0)
# Episode %d: PDE Error: %f (938, 0.0)
# Episode %d: PDE Error: %f (939, 0.0)
# Episode %d: PDE Error: %f (940, 0.0)
# Episode %d: PDE Error: %f (941, 0.0)
# Episode %d: PDE Error: %f (942, 0.0)
# Episode %d: PDE Error: %f (943, 0.0)
# Episode %d: PDE Error: %f (944, 0.0)
# Episode %d: PDE Error: %f (945, 0.0)
# Episode %d: PDE Error: %f (946, 0.0)
# Episode %d: PDE Error: %f (947, 0.0)
# Episode %d: PDE Error: %f (948, 0.0)
# Episode %d: PDE Error: %f (949, 0.0)
# Episode %d: PDE Error: %f (950, 0.0)
# Episode %d: PDE Error: %f (951, 0.0)
# Episode %d: PDE Error: %f (952, 0.0)
# Episode %d: PDE Error: %f (953, 0.0)
# Episode %d: PDE Error: %f (954, 0.0)
# Episode %d: PDE Error: %f (955, 0.0)
# Episode %d: PDE Error: %f (956, 0.0)
# Episode %d: PDE Error: %f (957, 0.0)
# Episode %d: PDE Error: %f (958, 0.0)
# Episode %d: PDE Error: %f (959, 0.0)
# Episode %d: PDE Error: %f (960, 0.0)
# Episode %d: PDE Error: %f (961, 0.0)
# Episode %d: PDE Error: %f (962, 0.0)
# Episode %d: PDE Error: %f (963, 0.0)
# Episode %d: PDE Error: %f (964, 0.0)
# Episode %d: PDE Error: %f (965, 0.0)
# Episode %d: PDE Error: %f (966, 0.0)
# Episode %d: PDE Error: %f (967, 0.0)
# Episode %d: PDE Error: %f (968, 0.0)
# Episode %d: PDE Error: %f (969, 0.0)
# Episode %d: PDE Error: %f (970, 0.0)
# Episode %d: PDE Error: %f (971, 0.0)
# Episode %d: PDE Error: %f (972, 0.0)
# Episode %d: PDE Error: %f (973, 0.0)
# Episode %d: PDE Error: %f (974, 0.0)
# Episode %d: PDE Error: %f (975, 0.0)
# Episode %d: PDE Error: %f (976, 0.0)
# Episode %d: PDE Error: %f (977, 0.0)
# Episode %d: PDE Error: %f (978, 0.0)
# Episode %d: PDE Error: %f (979, 0.0)
# Episode %d: PDE Error: %f (980, 0.0)
# Episode %d: PDE Error: %f (981, 0.0)
# Episode %d: PDE Error: %f (982, 0.0)
# Episode %d: PDE Error: %f (983, 0.0)
# Episode %d: PDE Error: %f (984, 0.0)
# Episode %d: PDE Error: %f (985, 0.0)
# Episode %d: PDE Error: %f (986, 0.0)
# Episode %d: PDE Error: %f (987, 0.0)
# Episode %d: PDE Error: %f (988, 0.0)
# Episode %d: PDE Error: %f (989, 0.0)
# Episode %d: PDE Error: %f (990, 0.0)
# Episode %d: PDE Error: %f (991, 0.0)
# Episode %d: PDE Error: %f (992, 0.0)
# Episode %d: PDE Error: %f (993, 0.0)
# Episode %d: PDE Error: %f (994, 0.0)
# Episode %d: PDE Error: %f (995, 0.0)
# Episode %d: PDE Error: %f (996, 0.0)
# Episode %d: PDE Error: %f (997, 0.0)
# Episode %d: PDE Error: %f (998, 0.0)
# Episode %d: PDE Error: %f (999, 0.0)
# Episode %d: PDE Error: %f (1000, 0.0)
# Episode %d: PDE Error: %f (1001, 0.0)
# Episode %d: PDE Error: %f (1002, 0.0)
# Episode %d: PDE Error: %f (1003, 0.0)
# Episode %d: PDE Error: %f (1004, 0.0)
# Episode %d: PDE Error: %f (1005, 0.0)
# Episode %d: PDE Error: %f (1006, 0.0)
# Episode %d: PDE Error: %f (1007, 0.0)
# Episode %d: PDE Error: %f (1008, 0.0)
# Episode %d: PDE Error: %f (1009, 0.0)
# Episode %d: PDE Error: %f (1010, 0.0)
# Episode %d: PDE Error: %f (1011, 0.0)
# Episode %d: PDE Error: %f (1012, 0.0)
# Episode %d: PDE Error: %f (1013, 0.0)
# Episode %d: PDE Error: %f (1014, 0.0)
# Episode %d: PDE Error: %f (1015, 0.0)
# Episode %d: PDE Error: %f (1016, 0.0)
# Episode %d: PDE Error: %f (1017, 0.0)
# Episode %d: PDE Error: %f (1018, 0.0)
# Episode %d: PDE Error: %f (1019, 0.0)
# Episode %d: PDE Error: %f (1020, 0.0)
# Episode %d: PDE Error: %f (1021, 0.0)
# Episode %d: PDE Error: %f (1022, 0.0)
# Episode %d: PDE Error: %f (1023, 0.0)
# Episode %d: PDE Error: %f (1024, 0.0)
# Episode %d: PDE Error: %f (1025, 0.0)
# Episode %d: PDE Error: %f (1026, 0.0)
# Episode %d: PDE Error: %f (1027, 0.0)
# Episode %d: PDE Error: %f (1028, 0.0)
# Episode %d: PDE Error: %f (1029, 0.0)
# Episode %d: PDE Error: %f (1030, 0.0)
# Episode %d: PDE Error: %f (1031, 0.0)
# Episode %d: PDE Error: %f (1032, 0.0)
# Episode %d: PDE Error: %f (1033, 0.0)
# Episode %d: PDE Error: %f (1034, 0.0)
# Episode %d: PDE Error: %f (1035, 0.0)
# Episode %d: PDE Error: %f (1036, 0.0)
# Episode %d: PDE Error: %f (1037, 0.0)
# Episode %d: PDE Error: %f (1038, 0.0)
# Episode %d: PDE Error: %f (1039, 0.0)
# Episode %d: PDE Error: %f (1040, 0.0)
# Episode %d: PDE Error: %f (1041, 0.0)
# Episode %d: PDE Error: %f (1042, 0.0)
# Episode %d: PDE Error: %f (1043, 0.0)
# Episode %d: PDE Error: %f (1044, 0.0)
# Episode %d: PDE Error: %f (1045, 0.0)
# Episode %d: PDE Error: %f (1046, 0.0)
# Episode %d: PDE Error: %f (1047, 0.0)
# Episode %d: PDE Error: %f (1048, 0.0)
# Episode %d: PDE Error: %f (1049, 0.0)
# Episode %d: PDE Error: %f (1050, 0.0)
# Episode %d: PDE Error: %f (1051, 0.0)
# Episode %d: PDE Error: %f (1052, 0.0)
# Episode %d: PDE Error: %f (1053, 0.0)
# Episode %d: PDE Error: %f (1054, 0.0)
# Episode %d: PDE Error: %f (1055, 0.0)
# Episode %d: PDE Error: %f (1056, 0.0)
# Episode %d: PDE Error: %f (1057, 0.0)
# Episode %d: PDE Error: %f (1058, 0.0)
# Episode %d: PDE Error: %f (1059, 0.0)
# Episode %d: PDE Error: %f (1060, 0.0)
# Episode %d: PDE Error: %f (1061, 0.0)
# Episode %d: PDE Error: %f (1062, 0.0)
# Episode %d: PDE Error: %f (1063, 0.0)
# Episode %d: PDE Error: %f (1064, 0.0)
# Episode %d: PDE Error: %f (1065, 0.0)
# Episode %d: PDE Error: %f (1066, 0.0)
# Episode %d: PDE Error: %f (1067, 0.0)
# Episode %d: PDE Error: %f (1068, 0.0)
# Episode %d: PDE Error: %f (1069, 0.0)
# Episode %d: PDE Error: %f (1070, 0.0)
# Episode %d: PDE Error: %f (1071, 0.0)
# Episode %d: PDE Error: %f (1072, 0.0)
# Episode %d: PDE Error: %f (1073, 0.0)
# Episode %d: PDE Error: %f (1074, 0.0)
# Episode %d: PDE Error: %f (1075, 0.0)
# Episode %d: PDE Error: %f (1076, 0.0)
# Episode %d: PDE Error: %f (1077, 0.0)
# Episode %d: PDE Error: %f (1078, 0.0)
# Episode %d: PDE Error: %f (1079, 0.0)
# Episode %d: PDE Error: %f (1080, 0.0)
# Episode %d: PDE Error: %f (1081, 0.0)
# Episode %d: PDE Error: %f (1082, 0.0)
# Episode %d: PDE Error: %f (1083, 0.0)
# Episode %d: PDE Error: %f (1084, 0.0)
# Episode %d: PDE Error: %f (1085, 0.0)
# Episode %d: PDE Error: %f (1086, 0.0)
# Episode %d: PDE Error: %f (1087, 0.0)
# Episode %d: PDE Error: %f (1088, 0.0)
# Episode %d: PDE Error: %f (1089, 0.0)
# Episode %d: PDE Error: %f (1090, 0.0)
# Episode %d: PDE Error: %f (1091, 0.0)
# Episode %d: PDE Error: %f (1092, 0.0)
# Episode %d: PDE Error: %f (1093, 0.0)
# Episode %d: PDE Error: %f (1094, 0.0)
# Episode %d: PDE Error: %f (1095, 0.0)
# Episode %d: PDE Error: %f (1096, 0.0)
# Episode %d: PDE Error: %f (1097, 0.0)
# Episode %d: PDE Error: %f (1098, 0.0)
# Episode %d: PDE Error: %f (1099, 0.0)
# Episode %d: PDE Error: %f (1100, 0.0)
# Episode %d: PDE Error: %f (1101, 0.0)
# Episode %d: PDE Error: %f (1102, 0.0)
# Episode %d: PDE Error: %f (1103, 0.0)
# Episode %d: PDE Error: %f (1104, 0.0)
# Episode %d: PDE Error: %f (1105, 0.0)
# Episode %d: PDE Error: %f (1106, 0.0)
# Episode %d: PDE Error: %f (1107, 0.0)
# Episode %d: PDE Error: %f (1108, 0.0)
# Episode %d: PDE Error: %f (1109, 0.0)
# Episode %d: PDE Error: %f (1110, 0.0)
# Episode %d: PDE Error: %f (1111, 0.0)
# Episode %d: PDE Error: %f (1112, 0.0)
# Episode %d: PDE Error: %f (1113, 0.0)
# Episode %d: PDE Error: %f (1114, 0.0)
# Episode %d: PDE Error: %f (1115, 0.0)
# Episode %d: PDE Error: %f (1116, 0.0)
# Episode %d: PDE Error: %f (1117, 0.0)
# Episode %d: PDE Error: %f (1118, 0.0)
# Episode %d: PDE Error: %f (1119, 0.0)
# Episode %d: PDE Error: %f (1120, 0.0)
# Episode %d: PDE Error: %f (1121, 0.0)
# Episode %d: PDE Error: %f (1122, 0.0)
# Episode %d: PDE Error: %f (1123, 0.0)
# Episode %d: PDE Error: %f (1124, 0.0)
# Episode %d: PDE Error: %f (1125, 0.0)
# Episode %d: PDE Error: %f (1126, 0.0)
# Episode %d: PDE Error: %f (1127, 0.0)
# Episode %d: PDE Error: %f (1128, 0.0)
# Episode %d: PDE Error: %f (1129, 0.0)
# Episode %d: PDE Error: %f (1130, 0.0)
# Episode %d: PDE Error: %f (1131, 0.0)
# Episode %d: PDE Error: %f (1132, 0.0)
# Episode %d: PDE Error: %f (1133, 0.0)
# Episode %d: PDE Error: %f (1134, 0.0)
# Episode %d: PDE Error: %f (1135, 0.0)
# Episode %d: PDE Error: %f (1136, 0.0)
# Episode %d: PDE Error: %f (1137, 0.0)
# Episode %d: PDE Error: %f (1138, 0.0)
# Episode %d: PDE Error: %f (1139, 0.0)
# Episode %d: PDE Error: %f (1140, 0.0)
# Episode %d: PDE Error: %f (1141, 0.0)
# Episode %d: PDE Error: %f (1142, 0.0)
# Episode %d: PDE Error: %f (1143, 0.0)
# Episode %d: PDE Error: %f (1144, 0.0)
# Episode %d: PDE Error: %f (1145, 0.0)
# Episode %d: PDE Error: %f (1146, 0.0)
# Episode %d: PDE Error: %f (1147, 0.0)
# Episode %d: PDE Error: %f (1148, 0.0)
# Episode %d: PDE Error: %f (1149, 0.0)
# Episode %d: PDE Error: %f (1150, 0.0)
# Episode %d: PDE Error: %f (1151, 0.0)
# Episode %d: PDE Error: %f (1152, 0.0)
# Episode %d: PDE Error: %f (1153, 0.0)
# Episode %d: PDE Error: %f (1154, 0.0)
# Episode %d: PDE Error: %f (1155, 0.0)
# Episode %d: PDE Error: %f (1156, 0.0)
# Episode %d: PDE Error: %f (1157, 0.0)
# Episode %d: PDE Error: %f (1158, 0.0)
# Episode %d: PDE Error: %f (1159, 0.0)
# Episode %d: PDE Error: %f (1160, 0.0)
# Episode %d: PDE Error: %f (1161, 0.0)
# Episode %d: PDE Error: %f (1162, 0.0)
# Episode %d: PDE Error: %f (1163, 0.0)
# Episode %d: PDE Error: %f (1164, 0.0)
# Episode %d: PDE Error: %f (1165, 0.0)
# Episode %d: PDE Error: %f (1166, 0.0)
# Episode %d: PDE Error: %f (1167, 0.0)
# Episode %d: PDE Error: %f (1168, 0.0)
# Episode %d: PDE Error: %f (1169, 0.0)
# Episode %d: PDE Error: %f (1170, 0.0)
# Episode %d: PDE Error: %f (1171, 0.0)
# Episode %d: PDE Error: %f (1172, 0.0)
# Episode %d: PDE Error: %f (1173, 0.0)
# Episode %d: PDE Error: %f (1174, 0.0)
# Episode %d: PDE Error: %f (1175, 0.0)
# Episode %d: PDE Error: %f (1176, 0.0)
# Episode %d: PDE Error: %f (1177, 0.0)
# Episode %d: PDE Error: %f (1178, 0.0)
# Episode %d: PDE Error: %f (1179, 0.0)
# Episode %d: PDE Error: %f (1180, 0.0)
# Episode %d: PDE Error: %f (1181, 0.0)
# Episode %d: PDE Error: %f (1182, 0.0)
# Episode %d: PDE Error: %f (1183, 0.0)
# Episode %d: PDE Error: %f (1184, 0.0)
# Episode %d: PDE Error: %f (1185, 0.0)
# Episode %d: PDE Error: %f (1186, 0.0)
# Episode %d: PDE Error: %f (1187, 0.0)
# Episode %d: PDE Error: %f (1188, 0.0)
# Episode %d: PDE Error: %f (1189, 0.0)
# Episode %d: PDE Error: %f (1190, 0.0)
# Episode %d: PDE Error: %f (1191, 0.0)
# Episode %d: PDE Error: %f (1192, 0.0)
# Episode %d: PDE Error: %f (1193, 0.0)
# Episode %d: PDE Error: %f (1194, 0.0)
# Episode %d: PDE Error: %f (1195, 0.0)
# Episode %d: PDE Error: %f (1196, 0.0)
# Episode %d: PDE Error: %f (1197, 0.0)
# Episode %d: PDE Error: %f (1198, 0.0)
# Episode %d: PDE Error: %f (1199, 0.0)
# Episode %d: PDE Error: %f (1200, 0.0)
# Episode %d: PDE Error: %f (1201, 0.0)
# Episode %d: PDE Error: %f (1202, 0.0)
# Episode %d: PDE Error: %f (1203, 0.0)
# Episode %d: PDE Error: %f (1204, 0.0)
# Episode %d: PDE Error: %f (1205, 0.0)
# Episode %d: PDE Error: %f (1206, 0.0)
# Episode %d: PDE Error: %f (1207, 0.0)
# Episode %d: PDE Error: %f (1208, 0.0)
# Episode %d: PDE Error: %f (1209, 0.0)
# Episode %d: PDE Error: %f (1210, 0.0)
# Episode %d: PDE Error: %f (1211, 0.0)
# Episode %d: PDE Error: %f (1212, 0.0)
# Episode %d: PDE Error: %f (1213, 0.0)
# Episode %d: PDE Error: %f (1214, 0.0)
# Episode %d: PDE Error: %f (1215, 0.0)
# Episode %d: PDE Error: %f (1216, 0.0)
# Episode %d: PDE Error: %f (1217, 0.0)
# Episode %d: PDE Error: %f (1218, 0.0)
# Episode %d: PDE Error: %f (1219, 0.0)
# Episode %d: PDE Error: %f (1220, 0.0)
# Episode %d: PDE Error: %f (1221, 0.0)
# Episode %d: PDE Error: %f (1222, 0.0)
# Episode %d: PDE Error: %f (1223, 0.0)
# Episode %d: PDE Error: %f (1224, 0.0)
# Episode %d: PDE Error: %f (1225, 0.0)
# Episode %d: PDE Error: %f (1226, 0.0)
# Episode %d: PDE Error: %f (1227, 0.0)
# Episode %d: PDE Error: %f (1228, 0.0)
# Episode %d: PDE Error: %f (1229, 0.0)
# Episode %d: PDE Error: %f (1230, 0.0)
# Episode %d: PDE Error: %f (1231, 0.0)
# Episode %d: PDE Error: %f (1232, 0.0)
# Episode %d: PDE Error: %f (1233, 0.0)
# Episode %d: PDE Error: %f (1234, 0.0)
# Episode %d: PDE Error: %f (1235, 0.0)
# Episode %d: PDE Error: %f (1236, 0.0)
# Episode %d: PDE Error: %f (1237, 0.0)
# Episode %d: PDE Error: %f (1238, 0.0)
# Episode %d: PDE Error: %f (1239, 0.0)
# Episode %d: PDE Error: %f (1240, 0.0)
# Episode %d: PDE Error: %f (1241, 0.0)
# Episode %d: PDE Error: %f (1242, 0.0)
# Episode %d: PDE Error: %f (1243, 0.0)
# Episode %d: PDE Error: %f (1244, 0.0)
# Episode %d: PDE Error: %f (1245, 0.0)
# Episode %d: PDE Error: %f (1246, 0.0)
# Episode %d: PDE Error: %f (1247, 0.0)
# Episode %d: PDE Error: %f (1248, 0.0)
# Episode %d: PDE Error: %f (1249, 0.0)
# Episode %d: PDE Error: %f (1250, 0.0)
# Episode %d: PDE Error: %f (1251, 0.0)
# Episode %d: PDE Error: %f (1252, 0.0)
# Episode %d: PDE Error: %f (1253, 0.0)
# Episode %d: PDE Error: %f (1254, 0.0)
# Episode %d: PDE Error: %f (1255, 0.0)
# Episode %d: PDE Error: %f (1256, 0.0)
# Episode %d: PDE Error: %f (1257, 0.0)
# Episode %d: PDE Error: %f (1258, 0.0)
# Episode %d: PDE Error: %f (1259, 0.0)
# Episode %d: PDE Error: %f (1260, 0.0)
# Episode %d: PDE Error: %f (1261, 0.0)
# Episode %d: PDE Error: %f (1262, 0.0)
# Episode %d: PDE Error: %f (1263, 0.0)
# Episode %d: PDE Error: %f (1264, 0.0)
# Episode %d: PDE Error: %f (1265, 0.0)
# Episode %d: PDE Error: %f (1266, 0.0)
# Episode %d: PDE Error: %f (1267, 0.0)
# Episode %d: PDE Error: %f (1268, 0.0)
# Episode %d: PDE Error: %f (1269, 0.0)
# Episode %d: PDE Error: %f (1270, 0.0)
# Episode %d: PDE Error: %f (1271, 0.0)
# Episode %d: PDE Error: %f (1272, 0.0)
# Episode %d: PDE Error: %f (1273, 0.0)
# Episode %d: PDE Error: %f (1274, 0.0)
# Episode %d: PDE Error: %f (1275, 0.0)
# Episode %d: PDE Error: %f (1276, 0.0)
# Episode %d: PDE Error: %f (1277, 0.0)
# Episode %d: PDE Error: %f (1278, 0.0)
# Episode %d: PDE Error: %f (1279, 0.0)
# Episode %d: PDE Error: %f (1280, 0.0)
# Episode %d: PDE Error: %f (1281, 0.0)
# Episode %d: PDE Error: %f (1282, 0.0)
# Episode %d: PDE Error: %f (1283, 0.0)
# Episode %d: PDE Error: %f (1284, 0.0)
# Episode %d: PDE Error: %f (1285, 0.0)
# Episode %d: PDE Error: %f (1286, 0.0)
# Episode %d: PDE Error: %f (1287, 0.0)
# Episode %d: PDE Error: %f (1288, 0.0)
# Episode %d: PDE Error: %f (1289, 0.0)
# Episode %d: PDE Error: %f (1290, 0.0)
# ...
# Episode %d: PDE Error: %f (5031, 0.0)
# Episode %d: PDE Error: %f (5032, 0.0)
# Episode %d: PDE Error: %f (5033, 0.0)
# Episode %d: PDE Error: %f (5034, 0.0)
# Episode %d: PDE Error: %f (5035, 0.0)
# Episode %d: PDE Error: %f (5036, 0.0)
# Episode %d: PDE Error: %f (5037, 0.0)
# Episode %d: PDE Error: %f (5038, 0.0)
# Episode %d: PDE Error: %f (5039, 0.0)
# Episode %d: PDE Error: %f (5040, 0.0)
# Episode %d: PDE Error: %f (5041, 0.0)
# Episode %d: PDE Error: %f (5042, 0.0)
# Episode %d: PDE Error: %f (5043, 0.0)
# Episode %d: PDE Error: %f (5044, 0.0)
# Episode %d: PDE Error: %f (5045, 0.0)
# Episode %d: PDE Error: %f (5046, 0.0)
# Episode %d: PDE Error: %f (5047, 0.0)
# Episode %d: PDE Error: %f (5048, 0.0)
# Episode %d: PDE Error: %f (5049, 0.0)
# Episode %d: PDE Error: %f (5050, 0.0)
# Episode %d: PDE Error: %f (5051, 0.0)
# Episode %d: PDE Error: %f (5052, 0.0)
# Episode %d: PDE Error: %f (5053, 0.0)
# Episode %d: PDE Error: %f (5054, 0.0)
# Episode %d: PDE Error: %f (5055, 0.0)
# Episode %d: PDE Error: %f (5056, 0.0)
# Episode %d: PDE Error: %f (5057, 0.0)
# Episode %d: PDE Error: %f (5058, 0.0)
# Episode %d: PDE Error: %f (5059, 0.0)
# Episode %d: PDE Error: %f (5060, 0.0)
# Episode %d: PDE Error: %f (5061, 0.0)
# Episode %d: PDE Error: %f (5062, 0.0)
# Episode %d: PDE Error: %f (5063, 0.0)
# Episode %d: PDE Error: %f (5064, 0.0)
# Episode %d: PDE Error: %f (5065, 0.0)
# Episode %d: PDE Error: %f (5066, 0.0)
# Episode %d: PDE Error: %f (5067, 0.0)
# Episode %d: PDE Error: %f (5068, 0.0)
# Episode %d: PDE Error: %f (5069, 0.0)
# Episode %d: PDE Error: %f (5070, 0.0)
# Episode %d: PDE Error: %f (5071, 0.0)
# Episode %d: PDE Error: %f (5072, 0.0)
# Episode %d: PDE Error: %f (5073, 0.0)
# Episode %d: PDE Error: %f (5074, 0.0)
# Episode %d: PDE Error: %f (5075, 0.0)
# Episode %d: PDE Error: %f (5076, 0.0)
# Episode %d: PDE Error: %f (5077, 0.0)
# Episode %d: PDE Error: %f (5078, 0.0)
# Episode %d: PDE Error: %f (5079, 0.0)
# Episode %d: PDE Error: %f (5080, 0.0)
# Episode %d: PDE Error: %f (5081, 0.0)
# Episode %d: PDE Error: %f (5082, 0.0)
# Episode %d: PDE Error: %f (5083, 0.0)
# Episode %d: PDE Error: %f (5084, 0.0)
# Episode %d: PDE Error: %f (5085, 0.0)
# Episode %d: PDE Error: %f (5086, 0.0)
# Episode %d: PDE Error: %f (5087, 0.0)
# Episode %d: PDE Error: %f (5088, 0.0)
# Episode %d: PDE Error: %f (5089, 0.0)
# Episode %d: PDE Error: %f (5090, 0.0)
# Episode %d: PDE Error: %f (5091, 0.0)
# Episode %d: PDE Error: %f (5092, 0.0)
# Episode %d: PDE Error: %f (5093, 0.0)
# Episode %d: PDE Error: %f (5094, 0.0)
# Episode %d: PDE Error: %f (5095, 0.0)
# Episode %d: PDE Error: %f (5096, 0.0)
# Episode %d: PDE Error: %f (5097, 0.0)
# Episode %d: PDE Error: %f (5098, 0.0)
# Episode %d: PDE Error: %f (5099, 0.0)
# Episode %d: PDE Error: %f (5100, 0.0)
# Episode %d: PDE Error: %f (5101, 0.0)
# Episode %d: PDE Error: %f (5102, 0.0)
# Episode %d: PDE Error: %f (5103, 0.0)
# Episode %d: PDE Error: %f (5104, 0.0)
# Episode %d: PDE Error: %f (5105, 0.0)
# Episode %d: PDE Error: %f (5106, 0.0)
# Episode %d: PDE Error: %f (5107, 0.0)
# Episode %d: PDE Error: %f (5108, 0.0)
# Episode %d: PDE Error: %f (5109, 0.0)
# Episode %d: PDE Error: %f (5110, 0.0)
# Episode %d: PDE Error: %f (5111, 0.0)
# Episode %d: PDE Error: %f (5112, 0.0)
# Episode %d: PDE Error: %f (5113, 0.0)
# Episode %d: PDE Error: %f (5114, 0.0)
# Episode %d: PDE Error: %f (5115, 0.0)
# Episode %d: PDE Error: %f (5116, 0.0)
# Episode %d: PDE Error: %f (5117, 0.0)
# Episode %d: PDE Error: %f (5118, 0.0)
# Episode %d: PDE Error: %f (5119, 0.0)
# Episode %d: PDE Error: %f (5120, 0.0)
# Episode %d: PDE Error: %f (5121, 0.0)
# Episode %d: PDE Error: %f (5122, 0.0)
# Episode %d: PDE Error: %f (5123, 0.0)
# Episode %d: PDE Error: %f (5124, 0.0)
# Episode %d: PDE Error: %f (5125, 0.0)
# Episode %d: PDE Error: %f (5126, 0.0)
# Episode %d: PDE Error: %f (5127, 0.0)
# Episode %d: PDE Error: %f (5128, 0.0)
# Episode %d: PDE Error: %f (5129, 0.0)
# Episode %d: PDE Error: %f (5130, 0.0)
# Episode %d: PDE Error: %f (5131, 0.0)
# Episode %d: PDE Error: %f (5132, 0.0)
# Episode %d: PDE Error: %f (5133, 0.0)
# Episode %d: PDE Error: %f (5134, 0.0)
# Episode %d: PDE Error: %f (5135, 0.0)
# Episode %d: PDE Error: %f (5136, 0.0)
# Episode %d: PDE Error: %f (5137, 0.0)
# Episode %d: PDE Error: %f (5138, 0.0)
# Episode %d: PDE Error: %f (5139, 0.0)
# Episode %d: PDE Error: %f (5140, 0.0)
# Episode %d: PDE Error: %f (5141, 0.0)
# Episode %d: PDE Error: %f (5142, 0.0)
# Episode %d: PDE Error: %f (5143, 0.0)
# Episode %d: PDE Error: %f (5144, 0.0)
# Episode %d: PDE Error: %f (5145, 0.0)
# Episode %d: PDE Error: %f (5146, 0.0)
# Episode %d: PDE Error: %f (5147, 0.0)
# Episode %d: PDE Error: %f (5148, 0.0)
# Episode %d: PDE Error: %f (5149, 0.0)
# Episode %d: PDE Error: %f (5150, 0.0)
# Episode %d: PDE Error: %f (5151, 0.0)
# Episode %d: PDE Error: %f (5152, 0.0)
# Episode %d: PDE Error: %f (5153, 0.0)
# Episode %d: PDE Error: %f (5154, 0.0)
# Episode %d: PDE Error: %f (5155, 0.0)
# Episode %d: PDE Error: %f (5156, 0.0)
# Episode %d: PDE Error: %f (5157, 0.0)
# Episode %d: PDE Error: %f (5158, 0.0)
# Episode %d: PDE Error: %f (5159, 0.0)
# Episode %d: PDE Error: %f (5160, 0.0)
# Episode %d: PDE Error: %f (5161, 0.0)
# Episode %d: PDE Error: %f (5162, 0.0)
# Episode %d: PDE Error: %f (5163, 0.0)
# Episode %d: PDE Error: %f (5164, 0.0)
# Episode %d: PDE Error: %f (5165, 0.0)
# Episode %d: PDE Error: %f (5166, 0.0)
# Episode %d: PDE Error: %f (5167, 0.0)
# Episode %d: PDE Error: %f (5168, 0.0)
# Episode %d: PDE Error: %f (5169, 0.0)
# Episode %d: PDE Error: %f (5170, 0.0)
# Episode %d: PDE Error: %f (5171, 0.0)
# Episode %d: PDE Error: %f (5172, 0.0)
# Episode %d: PDE Error: %f (5173, 0.0)
# Episode %d: PDE Error: %f (5174, 0.0)
# Episode %d: PDE Error: %f (5175, 0.0)
# Episode %d: PDE Error: %f (5176, 0.0)
# Episode %d: PDE Error: %f (5177, 0.0)
# Episode %d: PDE Error: %f (5178, 0.0)
# Episode %d: PDE Error: %f (5179, 0.0)
# Episode %d: PDE Error: %f (5180, 0.0)
# Episode %d: PDE Error: %f (5181, 0.0)
# Episode %d: PDE Error: %f (5182, 0.0)
# Episode %d: PDE Error: %f (5183, 0.0)
# Episode %d: PDE Error: %f (5184, 0.0)
# Episode %d: PDE Error: %f (5185, 0.0)
# Episode %d: PDE Error: %f (5186, 0.0)
# Episode %d: PDE Error: %f (5187, 0.0)
# Episode %d: PDE Error: %f (5188, 0.0)
# Episode %d: PDE Error: %f (5189, 0.0)
# Episode %d: PDE Error: %f (5190, 0.0)
# Episode %d: PDE Error: %f (5191, 0.0)
# Episode %d: PDE Error: %f (5192, 0.0)
# Episode %d: PDE Error: %f (5193, 0.0)
# Episode %d: PDE Error: %f (5194, 0.0)
# Episode %d: PDE Error: %f (5195, 0.0)
# Episode %d: PDE Error: %f (5196, 0.0)
# Episode %d: PDE Error: %f (5197, 0.0)
# Episode %d: PDE Error: %f (5198, 0.0)
# Episode %d: PDE Error: %f (5199, 0.0)
# Episode %d: PDE Error: %f (5200, 0.0)
# Episode %d: PDE Error: %f (5201, 0.0)
# Episode %d: PDE Error: %f (5202, 0.0)
# Episode %d: PDE Error: %f (5203, 0.0)
# Episode %d: PDE Error: %f (5204, 0.0)
# Episode %d: PDE Error: %f (5205, 0.0)
# Episode %d: PDE Error: %f (5206, 0.0)
# Episode %d: PDE Error: %f (5207, 0.0)
# Episode %d: PDE Error: %f (5208, 0.0)
# Episode %d: PDE Error: %f (5209, 0.0)
# Episode %d: PDE Error: %f (5210, 0.0)
# Episode %d: PDE Error: %f (5211, 0.0)
# Episode %d: PDE Error: %f (5212, 0.0)
# Episode %d: PDE Error: %f (5213, 0.0)
# Episode %d: PDE Error: %f (5214, 0.0)
# Episode %d: PDE Error: %f (5215, 0.0)
# Episode %d: PDE Error: %f (5216, 0.0)
# Episode %d: PDE Error: %f (5217, 0.0)
# Episode %d: PDE Error: %f (5218, 0.0)
# Episode %d: PDE Error: %f (5219, 0.0)
# Episode %d: PDE Error: %f (5220, 0.0)
# Episode %d: PDE Error: %f (5221, 0.0)
# Episode %d: PDE Error: %f (5222, 0.0)
# Episode %d: PDE Error: %f (5223, 0.0)
# Episode %d: PDE Error: %f (5224, 0.0)
# Episode %d: PDE Error: %f (5225, 0.0)
# Episode %d: PDE Error: %f (5226, 0.0)
# Episode %d: PDE Error: %f (5227, 0.0)
# Episode %d: PDE Error: %f (5228, 0.0)
# Episode %d: PDE Error: %f (5229, 0.0)
# Episode %d: PDE Error: %f (5230, 0.0)
# Episode %d: PDE Error: %f (5231, 0.0)
# Episode %d: PDE Error: %f (5232, 0.0)
# Episode %d: PDE Error: %f (5233, 0.0)
# Episode %d: PDE Error: %f (5234, 0.0)
# Episode %d: PDE Error: %f (5235, 0.0)
# Episode %d: PDE Error: %f (5236, 0.0)
# Episode %d: PDE Error: %f (5237, 0.0)
# Episode %d: PDE Error: %f (5238, 0.0)
# Episode %d: PDE Error: %f (5239, 0.0)
# Episode %d: PDE Error: %f (5240, 0.0)
# Episode %d: PDE Error: %f (5241, 0.0)
# Episode %d: PDE Error: %f (5242, 0.0)
# Episode %d: PDE Error: %f (5243, 0.0)
# Episode %d: PDE Error: %f (5244, 0.0)
# Episode %d: PDE Error: %f (5245, 0.0)
# Episode %d: PDE Error: %f (5246, 0.0)
# Episode %d: PDE Error: %f (5247, 0.0)
# Episode %d: PDE Error: %f (5248, 0.0)
# Episode %d: PDE Error: %f (5249, 0.0)
# Episode %d: PDE Error: %f (5250, 0.0)
# Episode %d: PDE Error: %f (5251, 0.0)
# Episode %d: PDE Error: %f (5252, 0.0)
# Episode %d: PDE Error: %f (5253, 0.0)
# Episode %d: PDE Error: %f (5254, 0.0)
# Episode %d: PDE Error: %f (5255, 0.0)
# Episode %d: PDE Error: %f (5256, 0.0)
# Episode %d: PDE Error: %f (5257, 0.0)
# Episode %d: PDE Error: %f (5258, 0.0)
# Episode %d: PDE Error: %f (5259, 0.0)
# Episode %d: PDE Error: %f (5260, 0.0)
# Episode %d: PDE Error: %f (5261, 0.0)
# Episode %d: PDE Error: %f (5262, 0.0)
# Episode %d: PDE Error: %f (5263, 0.0)
# Episode %d: PDE Error: %f (5264, 0.0)
# Episode %d: PDE Error: %f (5265, 0.0)
# Episode %d: PDE Error: %f (5266, 0.0)
# Episode %d: PDE Error: %f (5267, 0.0)
# Episode %d: PDE Error: %f (5268, 0.0)
# Episode %d: PDE Error: %f (5269, 0.0)
# Episode %d: PDE Error: %f (5270, 0.0)
# Episode %d: PDE Error: %f (5271, 0.0)
# Episode %d: PDE Error: %f (5272, 0.0)
# Episode %d: PDE Error: %f (5273, 0.0)
# Episode %d: PDE Error: %f (5274, 0.0)
# Episode %d: PDE Error: %f (5275, 0.0)
# Episode %d: PDE Error: %f (5276, 0.0)
# Episode %d: PDE Error: %f (5277, 0.0)
# Episode %d: PDE Error: %f (5278, 0.0)
# Episode %d: PDE Error: %f (5279, 0.0)
# Episode %d: PDE Error: %f (5280, 0.0)
# Episode %d: PDE Error: %f (5281, 0.0)
# Episode %d: PDE Error: %f (5282, 0.0)
# Episode %d: PDE Error: %f (5283, 0.0)
# Episode %d: PDE Error: %f (5284, 0.0)
# Episode %d: PDE Error: %f (5285, 0.0)
# Episode %d: PDE Error: %f (5286, 0.0)
# Episode %d: PDE Error: %f (5287, 0.0)
# Episode %d: PDE Error: %f (5288, 0.0)
# Episode %d: PDE Error: %f (5289, 0.0)
# Episode %d: PDE Error: %f (5290, 0.0)
# Episode %d: PDE Error: %f (5291, 0.0)
# Episode %d: PDE Error: %f (5292, 0.0)
# Episode %d: PDE Error: %f (5293, 0.0)
# Episode %d: PDE Error: %f (5294, 0.0)
# Episode %d: PDE Error: %f (5295, 0.0)
# Episode %d: PDE Error: %f (5296, 0.0)
# Episode %d: PDE Error: %f (5297, 0.0)
# Episode %d: PDE Error: %f (5298, 0.0)
# Episode %d: PDE Error: %f (5299, 0.0)
# Episode %d: PDE Error: %f (5300, 0.0)
# Episode %d: PDE Error: %f (5301, 0.0)
# Episode %d: PDE Error: %f (5302, 0.0)
# Episode %d: PDE Error: %f (5303, 0.0)
# Episode %d: PDE Error: %f (5304, 0.0)
# Episode %d: PDE Error: %f (5305, 0.0)
# Episode %d: PDE Error: %f (5306, 0.0)
# Episode %d: PDE Error: %f (5307, 0.0)
# Episode %d: PDE Error: %f (5308, 0.0)
# Episode %d: PDE Error: %f (5309, 0.0)
# Episode %d: PDE Error: %f (5310, 0.0)
# Episode %d: PDE Error: %f (5311, 0.0)
# Episode %d: PDE Error: %f (5312, 0.0)
# Episode %d: PDE Error: %f (5313, 0.0)
# Episode %d: PDE Error: %f (5314, 0.0)
# Episode %d: PDE Error: %f (5315, 0.0)
# Episode %d: PDE Error: %f (5316, 0.0)
# Episode %d: PDE Error: %f (5317, 0.0)
# Episode %d: PDE Error: %f (5318, 0.0)
# Episode %d: PDE Error: %f (5319, 0.0)
# Episode %d: PDE Error: %f (5320, 0.0)
# Episode %d: PDE Error: %f (5321, 0.0)
# Episode %d: PDE Error: %f (5322, 0.0)
# Episode %d: PDE Error: %f (5323, 0.0)
# Episode %d: PDE Error: %f (5324, 0.0)
# Episode %d: PDE Error: %f (5325, 0.0)
# Episode %d: PDE Error: %f (5326, 0.0)
# Episode %d: PDE Error: %f (5327, 0.0)
# Episode %d: PDE Error: %f (5328, 0.0)
# Episode %d: PDE Error: %f (5329, 0.0)
# Episode %d: PDE Error: %f (5330, 0.0)
# Episode %d: PDE Error: %f (5331, 0.0)
# Episode %d: PDE Error: %f (5332, 0.0)
# Episode %d: PDE Error: %f (5333, 0.0)
# Episode %d: PDE Error: %f (5334, 0.0)
# Episode %d: PDE Error: %f (5335, 0.0)
# Episode %d: PDE Error: %f (5336, 0.0)
# Episode %d: PDE Error: %f (5337, 0.0)
# Episode %d: PDE Error: %f (5338, 0.0)
# Episode %d: PDE Error: %f (5339, 0.0)
# Episode %d: PDE Error: %f (5340, 0.0)
# Episode %d: PDE Error: %f (5341, 0.0)
# Episode %d: PDE Error: %f (5342, 0.0)
# Episode %d: PDE Error: %f (5343, 0.0)
# Episode %d: PDE Error: %f (5344, 0.0)
# Episode %d: PDE Error: %f (5345, 0.0)
# Episode %d: PDE Error: %f (5346, 0.0)
# Episode %d: PDE Error: %f (5347, 0.0)
# Episode %d: PDE Error: %f (5348, 0.0)
# Episode %d: PDE Error: %f (5349, 0.0)
# Episode %d: PDE Error: %f (5350, 0.0)
# Episode %d: PDE Error: %f (5351, 0.0)
# Episode %d: PDE Error: %f (5352, 0.0)
# Episode %d: PDE Error: %f (5353, 0.0)
# Episode %d: PDE Error: %f (5354, 0.0)
# Episode %d: PDE Error: %f (5355, 0.0)
# Episode %d: PDE Error: %f (5356, 0.0)
# Episode %d: PDE Error: %f (5357, 0.0)
# Episode %d: PDE Error: %f (5358, 0.0)
# Episode %d: PDE Error: %f (5359, 0.0)
# Episode %d: PDE Error: %f (5360, 0.0)
# Episode %d: PDE Error: %f (5361, 0.0)
# Episode %d: PDE Error: %f (5362, 0.0)
# Episode %d: PDE Error: %f (5363, 0.0)
# Episode %d: PDE Error: %f (5364, 0.0)
# Episode %d: PDE Error: %f (5365, 0.0)
# Episode %d: PDE Error: %f (5366, 0.0)
# Episode %d: PDE Error: %f (5367, 0.0)
# Episode %d: PDE Error: %f (5368, 0.0)
# Episode %d: PDE Error: %f (5369, 0.0)
# Episode %d: PDE Error: %f (5370, 0.0)
# Episode %d: PDE Error: %f (5371, 0.0)
# Episode %d: PDE Error: %f (5372, 0.0)
# Episode %d: PDE Error: %f (5373, 0.0)
# Episode %d: PDE Error: %f (5374, 0.0)
# Episode %d: PDE Error: %f (5375, 0.0)
# Episode %d: PDE Error: %f (5376, 0.0)
# Episode %d: PDE Error: %f (5377, 0.0)
# Episode %d: PDE Error: %f (5378, 0.0)
# Episode %d: PDE Error: %f (5379, 0.0)
# Episode %d: PDE Error: %f (5380, 0.0)
# Episode %d: PDE Error: %f (5381, 0.0)
# Episode %d: PDE Error: %f (5382, 0.0)
# Episode %d: PDE Error: %f (5383, 0.0)
# Episode %d: PDE Error: %f (5384, 0.0)
# Episode %d: PDE Error: %f (5385, 0.0)
# Episode %d: PDE Error: %f (5386, 0.0)
# Episode %d: PDE Error: %f (5387, 0.0)
# Episode %d: PDE Error: %f (5388, 0.0)
# Episode %d: PDE Error: %f (5389, 0.0)
# Episode %d: PDE Error: %f (5390, 0.0)
# Episode %d: PDE Error: %f (5391, 0.0)
# Episode %d: PDE Error: %f (5392, 0.0)
# Episode %d: PDE Error: %f (5393, 0.0)
# Episode %d: PDE Error: %f (5394, 0.0)
# Episode %d: PDE Error: %f (5395, 0.0)
# Episode %d: PDE Error: %f (5396, 0.0)
# Episode %d: PDE Error: %f (5397, 0.0)
# Episode %d: PDE Error: %f (5398, 0.0)
# Episode %d: PDE Error: %f (5399, 0.0)
# Episode %d: PDE Error: %f (5400, 0.0)
# Episode %d: PDE Error: %f (5401, 0.0)
# Episode %d: PDE Error: %f (5402, 0.0)
# Episode %d: PDE Error: %f (5403, 0.0)
# Episode %d: PDE Error: %f (5404, 0.0)
# Episode %d: PDE Error: %f (5405, 0.0)
# Episode %d: PDE Error: %f (5406, 0.0)
# Episode %d: PDE Error: %f (5407, 0.0)
# Episode %d: PDE Error: %f (5408, 0.0)
# Episode %d: PDE Error: %f (5409, 0.0)
# Episode %d: PDE Error: %f (5410, 0.0)
# Episode %d: PDE Error: %f (5411, 0.0)
# Episode %d: PDE Error: %f (5412, 0.0)
# Episode %d: PDE Error: %f (5413, 0.0)
# Episode %d: PDE Error: %f (5414, 0.0)
# Episode %d: PDE Error: %f (5415, 0.0)
# Episode %d: PDE Error: %f (5416, 0.0)
# Episode %d: PDE Error: %f (5417, 0.0)
# Episode %d: PDE Error: %f (5418, 0.0)
# Episode %d: PDE Error: %f (5419, 0.0)
# Episode %d: PDE Error: %f (5420, 0.0)
# Episode %d: PDE Error: %f (5421, 0.0)
# Episode %d: PDE Error: %f (5422, 0.0)
# Episode %d: PDE Error: %f (5423, 0.0)
# Episode %d: PDE Error: %f (5424, 0.0)
# Episode %d: PDE Error: %f (5425, 0.0)
# Episode %d: PDE Error: %f (5426, 0.0)
# Episode %d: PDE Error: %f (5427, 0.0)
# Episode %d: PDE Error: %f (5428, 0.0)
# Episode %d: PDE Error: %f (5429, 0.0)
# Episode %d: PDE Error: %f (5430, 0.0)
# Episode %d: PDE Error: %f (5431, 0.0)
# Episode %d: PDE Error: %f (5432, 0.0)
# Episode %d: PDE Error: %f (5433, 0.0)
# Episode %d: PDE Error: %f (5434, 0.0)
# Episode %d: PDE Error: %f (5435, 0.0)
# Episode %d: PDE Error: %f (5436, 0.0)
# Episode %d: PDE Error: %f (5437, 0.0)
# Episode %d: PDE Error: %f (5438, 0.0)
# Episode %d: PDE Error: %f (5439, 0.0)
# Episode %d: PDE Error: %f (5440, 0.0)
# Episode %d: PDE Error: %f (5441, 0.0)
# Episode %d: PDE Error: %f (5442, 0.0)
# Episode %d: PDE Error: %f (5443, 0.0)
# Episode %d: PDE Error: %f (5444, 0.0)
# Episode %d: PDE Error: %f (5445, 0.0)
# Episode %d: PDE Error: %f (5446, 0.0)
# Episode %d: PDE Error: %f (5447, 0.0)
# Episode %d: PDE Error: %f (5448, 0.0)
# Episode %d: PDE Error: %f (5449, 0.0)
# *** KeyboardInterrupt exception caught in code being profiled.

# %% [markdown]
# ### Preference Damages

# %%
for_check = loadmat('temp_check.mat')

# %%
x = loadmat("climate_pars.mat")
for key,val in x.items():
    if key[0:2] == '__':
        pass
    elif key == 'filename' or key == 's' or key == 's0' or key =='s1' or key == 's2':
        pass
    else:
        (height, width) = val.shape
        if width == 1:
            if height == 1:    # one number
                exec(key +'=val[0,0]')
            else:              # a column array
                exec(key +'=val[:,0]')
        else:
            if height == 1:    # a row array
                exec(key +'=val[0,:]')
            else:
                exec(key +'=val')


start_time = time.time()

quadrature = 'legendre'   ###
theta = 5000
weight = 0.5

sigma_o = sigma_k
indic = 0    # redundant
beta_f = np.mean(par_lambda_McD)
# var_beta_f = np.var(par_lambda_McD)
var_beta_f = for_check['var_beta_f'][0][0]               # Worth discussion further
par_beta_f = par_lambda_McD
lambda0 = 1.0 / var_beta_f   # noted as lambda in MATLAB

xi_d = -1 * (1-alpha)
r_min = 0
r_max = 9
t_min = 0
t_max = 4000
k_min = 0
k_max = 9

tol = 1e-3

nr = 30
nt = 30
nk = 25
r = np.linspace(r_min, r_max, nr)
t = np.linspace(t_min, t_max, nt)
k = np.linspace(k_min, k_max, nk)

hr = r[1] - r[0]
hk = k[1] - k[0]
ht = t[1] - t[0]

(r_mat, t_mat, k_mat) = np.meshgrid(r,t,k, indexing = 'ij')
# r_mat = for_check['r_mat']
# t_mat = for_check['t_mat']
# k_mat = for_check['k_mat']

# time step
dt = 0.5
n = 30

# Power selection
power = 2


if power == 2:
    # Quad, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 2 * 0.0197
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0
elif power == 3:
    # Cubic, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 3 * 0.0079 * 1.5
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0

f_bar = 2
crit = 2

F0 = 1
sigma = np.matrix([[sigma_1 ** 2, rho_12], [rho_12, sigma_2 ** 2]])
Sigma = np.matrix([[var_beta_f,0,0],[0,sigma_1 ** 2, rho_12],[0, rho_12, sigma_2 ** 2]])
dee = np.matrix([gamma_1 + gamma_2 * F0 + gamma_2_plus * (F0 - f_bar) ** 2 * (F0>=2), beta_f, beta_f * F0])
sigma_d = float(np.sqrt(dee * Sigma * dee.T))

weight = 0.5  # on nordhaus
bar_gamma_2_plus = weight * 0 + (1 - weight) * gamma_2_plus

a = beta_f - 5 * np.sqrt(var_beta_f)
b = beta_f + 5 * np.sqrt(var_beta_f)

step_val1 = round(len(r) / 5)
step_val2 = round(len(t) / 5)
step_val3 = round(len(k) / 5)

v0 = alpha * r_mat + (1-alpha) * k_mat - beta_f * t_mat
v1_initial = v0 * np.ones(r_mat.shape)

v0_dr = centra_diff(v0,0,1,hr,1e-8)
v0_dt = centra_diff(v0,1,1,ht)
v0_dk = centra_diff(v0,2,1,hk)

v0_drr = centra_diff(v0,0,2,hr)
v0_dtt = centra_diff(v0,1,2,ht)
v0_dkk = centra_diff(v0,2,2,hk)

### FOC_all combinations
B1 = v0_dr - xi_d * (gamma_1 + gamma_2 * t_mat * beta_f + gamma_2_plus * (t_mat * beta_f - f_bar) ** (power - 1) * (t_mat >= (crit / beta_f))) * beta_f * np.exp(r_mat) - v0_dt * np.exp(r_mat)
C1 = - delta * alpha
e = -C1 / B1
e_hat = e
Acoeff = np.exp(r_mat - k_mat)
Bcoeff = delta * (1-alpha) / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5) + v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)
Ccoeff = -A_O  - Theta
f = ((-Bcoeff + np.sqrt(Bcoeff ** 2 - 4 * Acoeff * Ccoeff)) / (2 * Acoeff)) ** 2
i_k = (v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)) * (f ** 0.5) - Theta

# lower damage model:
a_1 = np.zeros(r_mat.shape);
b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
lambda_tilde_1 = lambda0 + c_1 * theta
beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1
I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta
#     R_1 = theta.*(I_1-(a_1+b_1.*beta_tilde_1+c_1./2.*(beta_tilde_1).^2+c_1./2./lambda_tilde_1));
R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)

# J_1_without_e = xi_d.*(gamma_1.*beta_tilde_1 ...
#         +gamma_2.*t_mat.*(beta_tilde_1.^2+1./lambda_tilde_1)).*exp(r_mat) ;

pi_tilde_1 = weight * np.exp(-theta * I_1)

r_multi = np.exp(r)
r_multi = r_multi[:,np.newaxis,np.newaxis]

# high damage model
if quadrature == 'legendre':

    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

elif quadrature == 'hermite':

    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

else: 

    raise TypeError('Wrong polynomials specification')

q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
I_2 = -1 / theta * np.log(scale_2)

#     q2_tilde_fnc = @(x) exp(-theta.*xi_d.*(gamma_1.*x ...
#         +gamma_2.*x.^2.*t_mat ...
#         +gamma_2_plus.*x.*(x.*t_mat-f_bar).^(power-1).*((x.*t_mat-f_bar)>=0)).*exp(r).*e_hat)./scale_2;

if quadrature == 'legendre':

    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

elif quadrature == 'hermite':

    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

J_2_with_e = J_2_without_e * e_hat

R_2 = theta * (I_2 - J_2_with_e)
pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
pi_tilde_2_norm = 1 - pi_tilde_1_norm

expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
C1 = -delta * alpha
e = -C1 / B1
e_star = e

J_1 = J_1_without_e * e_star
J_2 = J_2_without_e * e_star

I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

R_1 = theta * (I_1 - J_1)
R_2 = theta * (I_2 - J_2)
drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
RE_total = 1 / theta * RE

### PDE Inputs

A = -delta * np.ones(r_mat.shape)
B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
B_t = e_star * np.exp(r_mat)
C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
C_tt = np.zeros(r_mat.shape)

D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) + I_term #  + drift_distort + RE_total

stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
A = A.reshape(-1,1,order = 'F')
B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
D = D.reshape(-1,1,order = 'F')
v01 = v0.reshape(-1,1,order = 'F')
dt = dt

# %%
out_comp = out.reshape(v0.shape,order = "F")

# %%
out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)

out_comp = out.reshape(v0.shape,order = "F")
# episode = 0

# print("Episode %d: PDE Error: %f", (episode, np.max((out_comp - v0) / dt))) #Conjugate Gradient Error %f after %d iterations" % (episode, np.max((out_comp - v0) / dt), out[1], out[0]))
# v0 = out_comp
# vold = v1_initial

# %%
mdl = for_check['model']
np.max(abs(mdl['D'][0,0] - D))
# Out:
# 5.639895495068714e-10

# %%
mdl['A']
# Out:
# array([[array([[-0.01],
#        [-0.01],
#        [-0.01],
#        ...,
#        [-0.01],
#        [-0.01],
#        [-0.01]])]], dtype=object)

# %%
while np.max((out_comp - vold) / dt) > tol:
    # for iter in range(1):
        vold = v0
        v0_dr = centra_diff(v0,0,1,hr,1e-8)
        v0_dt = centra_diff(v0,1,1,ht)
        v0_dk = centra_diff(v0,2,1,hk)

        v0_drr = centra_diff(v0,0,2,hr)
        v0_dtt = centra_diff(v0,1,2,ht)
        v0_dkk = centra_diff(v0,2,2,hk)

        e_hat = e_star 

        f = ((A_O + Theta) * np.exp(-r_mat + k_mat) * (v0_dr * Gamma_r * Theta_r) / ((v0_dr * Gamma_r * Theta_r) * f ** (Theta_r) + (delta * (1-alpha) + v0_dk * Gamma))) ** (1 / (1 - Theta_r))
        f = f * (v0_dr > 1e-8)
        i_k = ((v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * Theta_r)) * (f ** (1 - Theta_r)) - Theta) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * Gamma * A_O - delta * (1-alpha) * Theta) / (delta * (1-alpha) + v0_dk * Gamma)

        # lower damage model:
        a_1 = np.zeros(r_mat.shape);
        b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
        c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
        lambda_tilde_1 = lambda0 + c_1 * theta
        beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1

        I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta

        R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
        J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)
        pi_tilde_1 = weight * np.exp(-theta * I_1)  

        #     r_multi = np.exp(r)
        #     r_multi = r_multi[:,np.newaxis,np.newaxis]

        ## high damage model
        if quadrature == 'legendre':

            scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

        elif quadrature == 'hermite':

            scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

        else: 

            raise TypeError('Wrong polynomials specification')

        q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
        I_2 = -1 / theta * np.log(scale_2)

        if quadrature == 'legendre':

            J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

        elif quadrature == 'hermite':

            J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
            J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

        J_2_with_e = J_2_without_e * e_hat
        R_2 = theta * (I_2 - J_2_with_e)
        pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
        pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
        pi_tilde_2_norm = 1 - pi_tilde_1_norm

        expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

        B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
        C1 = -delta * alpha
        e = -C1 / B1
        e_star = e

        J_1 = J_1_without_e * e_star
        J_2 = J_2_without_e * e_star

        I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

        R_1 = theta * (I_1 - J_1)
        R_2 = theta * (I_2 - J_2)
        drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

        RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
        RE_total = 1 / theta * RE 

        ### PDE Inputs

        A = -delta * np.ones(r_mat.shape)
        B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
        B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
        B_t = e_star * np.exp(r_mat)
        C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
        C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
        C_tt = np.zeros(r_mat.shape)

        D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) +  I_term # + drift_distort + RE_total

        stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
        A = A.reshape(-1,1,order = 'F')
        B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
        C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
        D = D.reshape(-1,1,order = 'F')
        v01 = v0.reshape(-1,1,order = 'F')
        dt = dt

        out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
        out_comp = out[2].reshape(v0.shape,order = "F")
        episode += 1

        v0 = out_comp
        print("Episode %d: PDE Error: %f", (episode, np.max((out_comp - v0) / dt)))
        
    print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# ### Jupyter noebook solves the model in 1084 seconds (3096 iterations) while MATLAB took about 200 seconds on my laptop. The differenceS of solved result and parameters are tiny as shown below.

# %%
for_check = loadmat('HJB_level_result.mat')
np.max(abs(for_check['out_comp'] - out_comp))
# Out:
# 1.438849039914203e-13

# %%
mdl = for_check['model']

# %%
np.max(abs(mdl['A'][0,0] - B))

# %%
np.max(abs(mdl['B'][0,0] - B))
# Out:
# 2.6314828679811775e-10

# %%
np.max(abs(mdl['C'][0,0] - C))
# Out:
# 0.0

# %%
np.max(abs(mdl['D'][0,0] - D))
# Out:
# 2.192690473634684e-15
