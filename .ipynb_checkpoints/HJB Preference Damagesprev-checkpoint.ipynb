# %%
# Required packages
import numpy as np
import pandas as pd
from scipy.io import loadmat
from scipy.stats import norm
import pdb
import warnings
import SolveLinSys
import time
import sys
sys.stdout.flush()

# %%
# Data Cleansing
x = loadmat('climate_pars.mat')

# %%
for key,val in x.items():
    if key[0:2] == '__':
        pass
    elif key == 'filename' or key == 's' or key == 's0' or key =='s1' or key == 's2':
        pass
    else:
        (height, width) = val.shape
        if width == 1:
            if height == 1:    # one number
                exec(key +'=val[0,0]')
            else:              # a column array
                exec(key +'=val[:,0]')
        else:
            if height == 1:    # a row array
                exec(key +'=val[0,:]')
            else:
                exec(key +'=val')

# %%
def centra_diff(data, dim, order, dlt, cap = None):  # compute the central difference derivatives for given input and dimensions
    res = np.zeros(data.shape)
    if order == 1:                    # first order derivatives
        
        if dim == 0:                  # to first dimension

            res[1:-1,:,:] = (1 / (2 * dlt)) * (data[2:,:,:] - data[:-2,:,:])
            res[-1,:,:] = (1 / dlt) * (data[-1,:,:] - data[-2,:,:])
            res[0,:,:] = (1 / dlt) * (data[1,:,:] - data[0,:,:])

        elif dim == 1:                # to second dimension

            res[:,1:-1,:] = (1 / (2 * dlt)) * (data[:,2:,:] - data[:,:-2,:])
            res[:,-1,:] = (1 / dlt) * (data[:,-1,:] - data[:,-2,:])
            res[:,0,:] = (1 / dlt) * (data[:,1,:] - data[:,0,:])

        elif dim == 2:                # to third dimension

            res[:,:,1:-1] = (1 / (2 * dlt)) * (data[:,:,2:] - data[:,:,:-2])
            res[:,:,-1] = (1 / dlt) * (data[:,:,-1] - data[:,:,-2])
            res[:,:,0] = (1 / dlt) * (data[:,:,1] - data[:,:,0])

        else:
            raise ValueError('wrong dim')
            
    elif order == 2:
        
        if dim == 0:                  # to first dimension

            res[1:-1,:,:] = (1 / dlt ** 2) * (data[2:,:,:] + data[:-2,:,:] - 2 * data[1:-1,:,:])
            res[-1,:,:] = (1 / dlt ** 2) * (data[-1,:,:] + data[-3,:,:] - 2 * data[-2,:,:])
            res[0,:,:] = (1 / dlt ** 2) * (data[2,:,:] + data[0,:,:] - 2 * data[1,:,:])

        elif dim == 1:                # to second dimension

            res[:,1:-1,:] = (1 / dlt ** 2) * (data[:,2:,:] + data[:,:-2,:] - 2 * data[:,1:-1,:])
            res[:,-1,:] = (1 / dlt ** 2) * (data[:,-1,:] + data[:,-3,:] - 2 * data[:,-2,:])
            res[:,0,:] = (1 / dlt ** 2) * (data[:,2,:] + data[:,0,:] - 2 * data[:,1,:])

        elif dim == 2:                # to third dimension

            res[:,:,1:-1] = (1 / dlt ** 2) * (data[:,:,2:] + data[:,:,:-2] - 2 * data[:,:,1:-1])
            res[:,:,-1] = (1 / dlt ** 2) * (data[:,:,-1] + data[:,:,-3] - 2 * data[:,:,-2])
            res[:,:,0] = (1 / dlt ** 2) * (data[:,:,2] + data[:,:,0] - 2 * data[:,:,1])

        else:
            raise ValueError('wrong dim')
        
    else:
        raise ValueError('wrong order')
        
    if cap is not None:
        res[res < cap] = cap
    return res

# %%
def quad_points_legendre(n):
    u = np.sqrt(1 / (4 - 1 / np.linspace(1,n-1,n-1)**2))  # upper diag
    [lambda0,V] = np.linalg.eig(np.diagflat(u,1) + np.diagflat(u,-1))  # V's column vectors are the main d
    i = np.argsort(lambda0)
    Vtop = V[0,:]
    Vtop = Vtop[i]
    w = 2 * Vtop ** 2
    return (lambda0[i],w)

def quad_points_hermite(n):
    i = np.linspace(1,n-1,n-1)
    a = np.sqrt(i / 2.0)
    [lambda0,V] = np.linalg.eig(np.diagflat(a,1) + np.diagflat(a,-1))
    i = np.argsort(lambda0)
    Vtop = V[0,:]
    Vtop = Vtop[i]
    w = np.sqrt(np.pi) * Vtop ** 2
    return (lambda0[i],w)


def quad_int(f,a,b,n,method):
    """
This function takes a function f to integrate from the multidimensional
interval specified by the row vectors a and b. N different points are used
in the quadrature method. Legendre and Hermite basis functions are
currently supported. In the case of Hermite methodology b is the normal
density and a is the normal mean.

Created by John Wilson (johnrwilson@uchicago.edu) & Updaed by Jiaming Wang (Jiamingwang@uchicago.edu)
    """
    if method == 'legendre':
        
        (xs,ws) = quad_points_legendre(n)
        g = lambda x: f((b-a) * 0.5  * x + (a + b) * 0.5)
        s = np.prod((b-a) * 0.5)                ######## Why using prod here?
        
    elif method == 'hermite':
        
        (xs,ws) = quad_points_hermite(n)
        g = lambda x: f(np.sqrt(2) * b * x + a)
        s = 1 / np.sqrt(np.pi)
        
    else:
        raise TypeError('Wrong polynomials specification')
    
    
    tp = type(a)
    if tp is np.float64 or tp is int or tp is np.double:
        res = 0
        for i in range(n):
#             pdb.set_trace()
            res += ws[i] * g(xs[i])
    else:
        raise ValueError('dimension is not 1')
    
    return s * res

# %% [markdown]
# ### Preference Damages

# %%
start_time = time.time()

quadrature = 'legendre'   ###
theta = 5000
weight = 0.5

sigma_o = sigma_k
indic = 0    # redundant
beta_f = np.mean(par_lambda_McD)
# var_beta_f = np.var(par_lambda_McD)
var_beta_f = for_check['var_beta_f'][0][0]               # Worth discussion further
par_beta_f = par_lambda_McD
lambda0 = 1.0 / var_beta_f   # noted as lambda in MATLAB

xi_d = -1 * (1-alpha)
r_min = 0
r_max = 9
t_min = 0
t_max = 4000
k_min = 0
k_max = 9

tol = 1e-10

nr = 30
nt = 30
nk = 25
r = np.linspace(r_min, r_max, nr)
t = np.linspace(t_min, t_max, nt)
k = np.linspace(k_min, k_max, nk)

hr = r[1] - r[0]
hk = k[1] - k[0]
ht = t[1] - t[0]

(r_mat, t_mat, k_mat) = np.meshgrid(r,t,k, indexing = 'ij')
# r_mat = for_check['r_mat']
# t_mat = for_check['t_mat']
# k_mat = for_check['k_mat']

# time step
dt = 0.5
n = 30

# Power selection
power = 2


if power == 2:
    # Quad, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 2 * 0.0197
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0
elif power == 3:
    # Cubic, max temp = 5:
    gamma_1 =  0.00017675
    gamma_2 =  2 * 0.0022
    gamma_2_plus = 3 * 0.0079 * 1.5
    sigma_1 = 0
    sigma_2 = 0
    rho_12 = 0
    
f_bar = 2
crit = 2

F0 = 1
sigma = np.matrix([[sigma_1 ** 2, rho_12], [rho_12, sigma_2 ** 2]])
Sigma = np.matrix([[var_beta_f,0,0],[0,sigma_1 ** 2, rho_12],[0, rho_12, sigma_2 ** 2]])
dee = np.matrix([gamma_1 + gamma_2 * F0 + gamma_2_plus * (F0 - f_bar) ** 2 * (F0>=2), beta_f, beta_f * F0])
sigma_d = float(np.sqrt(dee * Sigma * dee.T))

weight = 0.5  # on nordhaus
bar_gamma_2_plus = weight * 0 + (1 - weight) * gamma_2_plus

a = beta_f - 5 * np.sqrt(var_beta_f)
b = beta_f + 5 * np.sqrt(var_beta_f)

step_val1 = round(len(r) / 5)
step_val2 = round(len(t) / 5)
step_val3 = round(len(k) / 5)

v0 = alpha * r_mat + (1-alpha) * k_mat - beta_f * t_mat
v1_initial = v0 * np.ones(r_mat.shape)

v0_dr = centra_diff(v0,0,1,hr,1e-8)
v0_dt = centra_diff(v0,1,1,ht)
v0_dk = centra_diff(v0,2,1,hk)

v0_drr = centra_diff(v0,0,2,hr)
v0_dtt = centra_diff(v0,1,2,ht)
v0_dkk = centra_diff(v0,2,2,hk)

### FOC_all combinations
B1 = v0_dr - xi_d * (gamma_1 + gamma_2 * t_mat * beta_f + gamma_2_plus * (t_mat * beta_f - f_bar) ** (power - 1) * (t_mat >= (crit / beta_f))) * beta_f * np.exp(r_mat) - v0_dt * np.exp(r_mat)
C1 = - delta * alpha
e = -C1 / B1
e_hat = e
Acoeff = np.exp(r_mat - k_mat)
Bcoeff = delta * (1-alpha) / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5) + v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)
Ccoeff = -A_O  - Theta
f = ((-Bcoeff + np.sqrt(Bcoeff ** 2 - 4 * Acoeff * Ccoeff)) / (2 * Acoeff)) ** 2
i_k = (v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * 0.5)) * (f ** 0.5) - Theta

# lower damage model:
a_1 = np.zeros(r_mat.shape);
b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
lambda_tilde_1 = lambda0 + c_1 * theta
beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1
I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta
#     R_1 = theta.*(I_1-(a_1+b_1.*beta_tilde_1+c_1./2.*(beta_tilde_1).^2+c_1./2./lambda_tilde_1));
R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)

# J_1_without_e = xi_d.*(gamma_1.*beta_tilde_1 ...
#         +gamma_2.*t_mat.*(beta_tilde_1.^2+1./lambda_tilde_1)).*exp(r_mat) ;

pi_tilde_1 = weight * np.exp(-theta * I_1)

r_multi = np.exp(r)
r_multi = r_multi[:,np.newaxis,np.newaxis]

# high damage model
if quadrature == 'legendre':
    
    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   
    
elif quadrature == 'hermite':
    
    scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')
    
else: 
    
    raise TypeError('Wrong polynomials specification')

q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
I_2 = -1 / theta * np.log(scale_2)

#     q2_tilde_fnc = @(x) exp(-theta.*xi_d.*(gamma_1.*x ...
#         +gamma_2.*x.^2.*t_mat ...
#         +gamma_2_plus.*x.*(x.*t_mat-f_bar).^(power-1).*((x.*t_mat-f_bar)>=0)).*exp(r).*e_hat)./scale_2;

if quadrature == 'legendre':
    
    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')
    
elif quadrature == 'hermite':
    
    J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) # * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
    J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')
    
J_2_with_e = J_2_without_e * e_hat

R_2 = theta * (I_2 - J_2_with_e)
pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
pi_tilde_2_norm = 1 - pi_tilde_1_norm

expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
C1 = -delta * alpha
e = -C1 / B1
e_star = e

J_1 = J_1_without_e * e_star
J_2 = J_2_without_e * e_star

I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

R_1 = theta * (I_1 - J_1)
R_2 = theta * (I_2 - J_2)
drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
RE_total = 1 / theta * RE

### PDE Inputs

A = -delta * np.ones(r_mat.shape)
B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
B_t = e_star * np.exp(r_mat)
C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
C_tt = np.zeros(r_mat.shape)

D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) + I_term #  + drift_distort + RE_total

stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
A = A.reshape(-1,1,order = 'F')
B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
D = D.reshape(-1,1,order = 'F')
v01 = v0.reshape(-1,1,order = 'F')
dt = dt

out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)

out_comp = out[2].reshape(v0.shape,order = "F")
episode = 0

print("Episode %d: PDE Error: %f, Conjugate Gradient Error %f after %d iterations" % (episode, np.max((out_comp - v0) / dt), out[1], out[0]))
v0 = out_comp
vold = v1_initial

while np.max((out_comp - vold) / dt) > tol:
# for iter in range(1):
    vold = v0
    v0_dr = centra_diff(v0,0,1,hr,1e-8)
    v0_dt = centra_diff(v0,1,1,ht)
    v0_dk = centra_diff(v0,2,1,hk)

    v0_drr = centra_diff(v0,0,2,hr)
    v0_dtt = centra_diff(v0,1,2,ht)
    v0_dkk = centra_diff(v0,2,2,hk)

    e_hat = e_star 

    f = ((A_O + Theta) * np.exp(-r_mat + k_mat) * (v0_dr * Gamma_r * Theta_r) / ((v0_dr * Gamma_r * Theta_r) * f ** (Theta_r) + (delta * (1-alpha) + v0_dk * Gamma))) ** (1 / (1 - Theta_r))
    f = f * (v0_dr > 1e-8)
    i_k = ((v0_dk * Gamma / (np.exp(-r_mat + k_mat) * v0_dr * Gamma_r * Theta_r)) * (f ** (1 - Theta_r)) - Theta) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * Gamma * A_O - delta * (1-alpha) * Theta) / (delta * (1-alpha) + v0_dk * Gamma)

    # lower damage model:
    a_1 = np.zeros(r_mat.shape);
    b_1 = xi_d * e_hat * np.exp(r_mat) * gamma_1
    c_1 = 2 * xi_d * e_hat * np.exp(r_mat) * t_mat * gamma_2
    lambda_tilde_1 = lambda0 + c_1 * theta
    beta_tilde_1 = beta_f - c_1 * theta / lambda_tilde_1 * beta_f - theta / lambda_tilde_1 * b_1

    I_1 = a_1 - 0.5 * np.log(lambda0) / theta + 0.5 * np.log(lambda_tilde_1) / theta + 0.5 * lambda0 * beta_f ** 2 / theta - 0.5 * lambda_tilde_1 * (beta_tilde_1) ** 2 / theta

    R_1 = theta * (I_1 - (a_1 + b_1 * beta_tilde_1 + c_1 * beta_tilde_1 ** 2 + c_1 / lambda_tilde_1))
    J_1_without_e = xi_d * (gamma_1 * beta_tilde_1 + gamma_2 * t_mat * (beta_tilde_1 ** 2 + 1 / lambda_tilde_1)) * np.exp(r_mat)
    pi_tilde_1 = weight * np.exp(-theta * I_1)  

    #     r_multi = np.exp(r)
    #     r_multi = r_multi[:,np.newaxis,np.newaxis]

    ## high damage model
    if quadrature == 'legendre':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, a, b, n, 'legendre')   

    elif quadrature == 'hermite':

        scale_2_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat)  * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        scale_2 = quad_int(scale_2_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    else: 

        raise TypeError('Wrong polynomials specification')

    q2_tilde_fnc = lambda x: np.exp(-theta * xi_d * (gamma_1 * x + gamma_2 * x ** 2 * t_mat + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * r_multi * e_hat) / scale_2
    I_2 = -1 / theta * np.log(scale_2)

    if quadrature == 'legendre':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, a, b, n, 'legendre')

    elif quadrature == 'hermite':

        J_2_without_e_fnc = lambda x: xi_d * np.exp(r_mat) * q2_tilde_fnc(x) * (gamma_1 * x + gamma_2 * t_mat * x ** 2 + gamma_2_plus * x * (x * t_mat - f_bar) ** (power - 1) * ((x * t_mat - f_bar) >= 0)) * norm.pdf(x,beta_f,np.sqrt(var_beta_f))
        J_2_without_e = quad_int(J_2_without_e_fnc, beta_f, np.sqrt(var_beta_f), n, 'hermite')

    J_2_with_e = J_2_without_e * e_hat
    R_2 = theta * (I_2 - J_2_with_e)
    pi_tilde_2 = (1 - weight) * np.exp(-theta * I_2)
    pi_tilde_1_norm = pi_tilde_1 / (pi_tilde_1 + pi_tilde_2)
    pi_tilde_2_norm = 1 - pi_tilde_1_norm

    expec_e_sum = (pi_tilde_1_norm * J_1_without_e + pi_tilde_2_norm * J_2_without_e)

    B1 = v0_dr - v0_dt * np.exp(r_mat) - expec_e_sum
    C1 = -delta * alpha
    e = -C1 / B1
    e_star = e

    J_1 = J_1_without_e * e_star
    J_2 = J_2_without_e * e_star

    I_term = -1 / theta * np.log(pi_tilde_1 + pi_tilde_2)

    R_1 = theta * (I_1 - J_1)
    R_2 = theta * (I_2 - J_2)
    drift_distort = (pi_tilde_1_norm * J_1 + pi_tilde_2_norm * J_2)

    RE = pi_tilde_1_norm * R_1 + pi_tilde_2_norm * R_2 + pi_tilde_1_norm * np.log(pi_tilde_1_norm / weight) + pi_tilde_2_norm * np.log(pi_tilde_2_norm / (1 - weight))
    RE_total = 1 / theta * RE 

    ### PDE Inputs

    A = -delta * np.ones(r_mat.shape)
    B_r = -e_star + Gamma_r * (f ** Theta_r) - 0.5 * (sigma_r ** 2)
    B_k = Alpha + Gamma * np.log(1 + i_k / Theta) - 0.5 * (sigma_k ** 2)
    B_t = e_star * np.exp(r_mat)
    C_rr = 0.5 * sigma_r ** 2 * np.ones(r_mat.shape)
    C_kk = 0.5 * sigma_k ** 2 * np.ones(r_mat.shape)
    C_tt = np.zeros(r_mat.shape)

    D = delta * alpha * np.log(e_star) + delta * alpha * r_mat + delta * (1 - alpha) * (np.log(A_O - i_k - f * np.exp(r_mat - k_mat)) + k_mat) +  I_term # + drift_distort + RE_total

    stateSpace = np.hstack([r_mat.reshape(-1,1,order = 'F'),t_mat.reshape(-1,1,order = 'F'),k_mat.reshape(-1,1,order = 'F')])
    A = A.reshape(-1,1,order = 'F')
    B = np.hstack([B_r.reshape(-1,1,order = 'F'),B_t.reshape(-1,1,order = 'F'),B_k.reshape(-1,1,order = 'F')])
    C = np.hstack([C_rr.reshape(-1,1,order = 'F'), C_tt.reshape(-1,1,order = 'F'), C_kk.reshape(-1,1,order = 'F')])
    D = D.reshape(-1,1,order = 'F')
    v01 = v0.reshape(-1,1,order = 'F')
    dt = dt

    out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
    out_comp = out[2].reshape(v0.shape,order = "F")
    episode += 1

    v0 = out_comp
    print("Episode %d: PDE Error: %f, Conjugate Gradient Error %f after %d iterations" % (episode, np.max((out_comp - vold) / dt), out[1], out[0]))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Episode 0: PDE Error: 0.054144, Conjugate Gradient Error 0.000000 after 10 iterations
# Episode 1: PDE Error: 0.057650, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 2: PDE Error: 0.057267, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 3: PDE Error: 0.056872, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 4: PDE Error: 0.056483, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 5: PDE Error: 0.056101, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 6: PDE Error: 0.055725, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 7: PDE Error: 0.055355, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 8: PDE Error: 0.054990, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 9: PDE Error: 0.054631, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 10: PDE Error: 0.054277, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 11: PDE Error: 0.053928, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 12: PDE Error: 0.053584, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 13: PDE Error: 0.053244, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 14: PDE Error: 0.052909, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 15: PDE Error: 0.052578, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 16: PDE Error: 0.052251, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 17: PDE Error: 0.051928, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 18: PDE Error: 0.051609, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 19: PDE Error: 0.051294, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 20: PDE Error: 0.050982, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 21: PDE Error: 0.050673, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 22: PDE Error: 0.050368, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 23: PDE Error: 0.050067, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 24: PDE Error: 0.049768, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 25: PDE Error: 0.049472, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 26: PDE Error: 0.049180, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 27: PDE Error: 0.048890, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 28: PDE Error: 0.048603, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 29: PDE Error: 0.048318, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 30: PDE Error: 0.048037, Conjugate Gradient Error 0.000000 after 8 iterations
# Episode 31: PDE Error: 0.047758, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 32: PDE Error: 0.047481, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 33: PDE Error: 0.047207, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 34: PDE Error: 0.046935, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 35: PDE Error: 0.046666, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 36: PDE Error: 0.046398, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 37: PDE Error: 0.046134, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 38: PDE Error: 0.045871, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 39: PDE Error: 0.045610, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 40: PDE Error: 0.045352, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 41: PDE Error: 0.045095, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 42: PDE Error: 0.044841, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 43: PDE Error: 0.044588, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 44: PDE Error: 0.044338, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 45: PDE Error: 0.044089, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 46: PDE Error: 0.043843, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 47: PDE Error: 0.043598, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 48: PDE Error: 0.043354, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 49: PDE Error: 0.043113, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 50: PDE Error: 0.042874, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 51: PDE Error: 0.042636, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 52: PDE Error: 0.042400, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 53: PDE Error: 0.042165, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 54: PDE Error: 0.041932, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 55: PDE Error: 0.041701, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 56: PDE Error: 0.041471, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 57: PDE Error: 0.041243, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 58: PDE Error: 0.041017, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 59: PDE Error: 0.040792, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 60: PDE Error: 0.040568, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 61: PDE Error: 0.040346, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 62: PDE Error: 0.040126, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 63: PDE Error: 0.039907, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 64: PDE Error: 0.039689, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 65: PDE Error: 0.039473, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 66: PDE Error: 0.039258, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 67: PDE Error: 0.039045, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 68: PDE Error: 0.038833, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 69: PDE Error: 0.038622, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 70: PDE Error: 0.038413, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 71: PDE Error: 0.038205, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 72: PDE Error: 0.037998, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 73: PDE Error: 0.037793, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 74: PDE Error: 0.037589, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 75: PDE Error: 0.037386, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 76: PDE Error: 0.037185, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 77: PDE Error: 0.036984, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 78: PDE Error: 0.036785, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 79: PDE Error: 0.036588, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 80: PDE Error: 0.036391, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 81: PDE Error: 0.036196, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 82: PDE Error: 0.036001, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 83: PDE Error: 0.035808, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 84: PDE Error: 0.035617, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 85: PDE Error: 0.035426, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 86: PDE Error: 0.035237, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 87: PDE Error: 0.035048, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 88: PDE Error: 0.034861, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 89: PDE Error: 0.034675, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 90: PDE Error: 0.034490, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 91: PDE Error: 0.034306, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 92: PDE Error: 0.034123, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 93: PDE Error: 0.033942, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 94: PDE Error: 0.033761, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 95: PDE Error: 0.033581, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 96: PDE Error: 0.033403, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 97: PDE Error: 0.033226, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 98: PDE Error: 0.033049, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 99: PDE Error: 0.032874, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 100: PDE Error: 0.032700, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 101: PDE Error: 0.032526, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 102: PDE Error: 0.032354, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 103: PDE Error: 0.032183, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 104: PDE Error: 0.032013, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 105: PDE Error: 0.031844, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 106: PDE Error: 0.031676, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 107: PDE Error: 0.031510, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 108: PDE Error: 0.031345, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 109: PDE Error: 0.031181, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 110: PDE Error: 0.031017, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 111: PDE Error: 0.030855, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 112: PDE Error: 0.030694, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 113: PDE Error: 0.030534, Conjugate Gradient Error 0.000000 after 7 iterations
# Episode 114: PDE Error: 0.030375, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 115: PDE Error: 0.030217, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 116: PDE Error: 0.030060, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 117: PDE Error: 0.029904, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 118: PDE Error: 0.029748, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 119: PDE Error: 0.029594, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 120: PDE Error: 0.029441, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 121: PDE Error: 0.029288, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 122: PDE Error: 0.029137, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 123: PDE Error: 0.028986, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 124: PDE Error: 0.028836, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 125: PDE Error: 0.028688, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 126: PDE Error: 0.028540, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 127: PDE Error: 0.028393, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 128: PDE Error: 0.028246, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 129: PDE Error: 0.028101, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 130: PDE Error: 0.027957, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 131: PDE Error: 0.027813, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 132: PDE Error: 0.027670, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 133: PDE Error: 0.027528, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 134: PDE Error: 0.027387, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 135: PDE Error: 0.027247, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 136: PDE Error: 0.027107, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 137: PDE Error: 0.026969, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 138: PDE Error: 0.026830, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 139: PDE Error: 0.026693, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 140: PDE Error: 0.026557, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 141: PDE Error: 0.026421, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 142: PDE Error: 0.026287, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 143: PDE Error: 0.026152, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 144: PDE Error: 0.026019, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 145: PDE Error: 0.025886, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 146: PDE Error: 0.025755, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 147: PDE Error: 0.025623, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 148: PDE Error: 0.025493, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 149: PDE Error: 0.025363, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 150: PDE Error: 0.025234, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 151: PDE Error: 0.025106, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 152: PDE Error: 0.024978, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 153: PDE Error: 0.024851, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 154: PDE Error: 0.024725, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 155: PDE Error: 0.024600, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 156: PDE Error: 0.024475, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 157: PDE Error: 0.024351, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 158: PDE Error: 0.024227, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 159: PDE Error: 0.024104, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 160: PDE Error: 0.023982, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 161: PDE Error: 0.023861, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 162: PDE Error: 0.023740, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 163: PDE Error: 0.023620, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 164: PDE Error: 0.023500, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 165: PDE Error: 0.023381, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 166: PDE Error: 0.023263, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 167: PDE Error: 0.023145, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 168: PDE Error: 0.023028, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 169: PDE Error: 0.022912, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 170: PDE Error: 0.022796, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 171: PDE Error: 0.022681, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 172: PDE Error: 0.022566, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 173: PDE Error: 0.022452, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 174: PDE Error: 0.022339, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 175: PDE Error: 0.022226, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 176: PDE Error: 0.022114, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 177: PDE Error: 0.022002, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 178: PDE Error: 0.021892, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 179: PDE Error: 0.021781, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 180: PDE Error: 0.021671, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 181: PDE Error: 0.021562, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 182: PDE Error: 0.021453, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 183: PDE Error: 0.021345, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 184: PDE Error: 0.021238, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 185: PDE Error: 0.021131, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 186: PDE Error: 0.021024, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 187: PDE Error: 0.020919, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 188: PDE Error: 0.020813, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 189: PDE Error: 0.020708, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 190: PDE Error: 0.020604, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 191: PDE Error: 0.020500, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 192: PDE Error: 0.020397, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 193: PDE Error: 0.020295, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 194: PDE Error: 0.020193, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 195: PDE Error: 0.020091, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 196: PDE Error: 0.019990, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 197: PDE Error: 0.019890, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 198: PDE Error: 0.019790, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 199: PDE Error: 0.019690, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 200: PDE Error: 0.019591, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 201: PDE Error: 0.019493, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 202: PDE Error: 0.019395, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 203: PDE Error: 0.019298, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 204: PDE Error: 0.019201, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 205: PDE Error: 0.019104, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 206: PDE Error: 0.019008, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 207: PDE Error: 0.018913, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 208: PDE Error: 0.018818, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 209: PDE Error: 0.018724, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 210: PDE Error: 0.018630, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 211: PDE Error: 0.018536, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 212: PDE Error: 0.018443, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 213: PDE Error: 0.018351, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 214: PDE Error: 0.018259, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 215: PDE Error: 0.018167, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 216: PDE Error: 0.018076, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 217: PDE Error: 0.017985, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 218: PDE Error: 0.017895, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 219: PDE Error: 0.017805, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 220: PDE Error: 0.017716, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 221: PDE Error: 0.017627, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 222: PDE Error: 0.017539, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 223: PDE Error: 0.017451, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 224: PDE Error: 0.017364, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 225: PDE Error: 0.017277, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 226: PDE Error: 0.017190, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 227: PDE Error: 0.017104, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 228: PDE Error: 0.017018, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 229: PDE Error: 0.016933, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 230: PDE Error: 0.016848, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 231: PDE Error: 0.016764, Conjugate Gradient Error 0.000000 after 6 iterations
# Episode 232: PDE Error: 0.016680, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 233: PDE Error: 0.016597, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 234: PDE Error: 0.016513, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 235: PDE Error: 0.016431, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 236: PDE Error: 0.016349, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 237: PDE Error: 0.016267, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 238: PDE Error: 0.016185, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 239: PDE Error: 0.016104, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 240: PDE Error: 0.016024, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 241: PDE Error: 0.015944, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 242: PDE Error: 0.015864, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 243: PDE Error: 0.015785, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 244: PDE Error: 0.015706, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 245: PDE Error: 0.015627, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 246: PDE Error: 0.015549, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 247: PDE Error: 0.015471, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 248: PDE Error: 0.015394, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 249: PDE Error: 0.015317, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 250: PDE Error: 0.015240, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 251: PDE Error: 0.015164, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 252: PDE Error: 0.015088, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 253: PDE Error: 0.015013, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 254: PDE Error: 0.014938, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 255: PDE Error: 0.014863, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 256: PDE Error: 0.014789, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 257: PDE Error: 0.014715, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 258: PDE Error: 0.014641, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 259: PDE Error: 0.014568, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 260: PDE Error: 0.014495, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 261: PDE Error: 0.014423, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 262: PDE Error: 0.014351, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 263: PDE Error: 0.014279, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 264: PDE Error: 0.014208, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 265: PDE Error: 0.014137, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 266: PDE Error: 0.014066, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 267: PDE Error: 0.013996, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 268: PDE Error: 0.013926, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 269: PDE Error: 0.013856, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 270: PDE Error: 0.013787, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 271: PDE Error: 0.013718, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 272: PDE Error: 0.013650, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 273: PDE Error: 0.013582, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 274: PDE Error: 0.013514, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 275: PDE Error: 0.013446, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 276: PDE Error: 0.013379, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 277: PDE Error: 0.013312, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 278: PDE Error: 0.013246, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 279: PDE Error: 0.013180, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 280: PDE Error: 0.013114, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 281: PDE Error: 0.013049, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 282: PDE Error: 0.012984, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 283: PDE Error: 0.012919, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 284: PDE Error: 0.012854, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 285: PDE Error: 0.012790, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 286: PDE Error: 0.012726, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 287: PDE Error: 0.012663, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 288: PDE Error: 0.012599, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 289: PDE Error: 0.012537, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 290: PDE Error: 0.012474, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 291: PDE Error: 0.012412, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 292: PDE Error: 0.012350, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 293: PDE Error: 0.012288, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 294: PDE Error: 0.012227, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 295: PDE Error: 0.012166, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 296: PDE Error: 0.012105, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 297: PDE Error: 0.012045, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 298: PDE Error: 0.011984, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 299: PDE Error: 0.011925, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 300: PDE Error: 0.011865, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 301: PDE Error: 0.011806, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 302: PDE Error: 0.011747, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 303: PDE Error: 0.011688, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 304: PDE Error: 0.011630, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 305: PDE Error: 0.011572, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 306: PDE Error: 0.011514, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 307: PDE Error: 0.011457, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 308: PDE Error: 0.011399, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 309: PDE Error: 0.011343, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 310: PDE Error: 0.011286, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 311: PDE Error: 0.011230, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 312: PDE Error: 0.011174, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 313: PDE Error: 0.011118, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 314: PDE Error: 0.011062, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 315: PDE Error: 0.011007, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 316: PDE Error: 0.010952, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 317: PDE Error: 0.010897, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 318: PDE Error: 0.010843, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 319: PDE Error: 0.010789, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 320: PDE Error: 0.010735, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 321: PDE Error: 0.010681, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 322: PDE Error: 0.010628, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 323: PDE Error: 0.010575, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 324: PDE Error: 0.010522, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 325: PDE Error: 0.010470, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 326: PDE Error: 0.010418, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 327: PDE Error: 0.010366, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 328: PDE Error: 0.010314, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 329: PDE Error: 0.010262, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 330: PDE Error: 0.010211, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 331: PDE Error: 0.010160, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 332: PDE Error: 0.010109, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 333: PDE Error: 0.010059, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 334: PDE Error: 0.010009, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 335: PDE Error: 0.009959, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 336: PDE Error: 0.009909, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 337: PDE Error: 0.009860, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 338: PDE Error: 0.009810, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 339: PDE Error: 0.009761, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 340: PDE Error: 0.009713, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 341: PDE Error: 0.009664, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 342: PDE Error: 0.009616, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 343: PDE Error: 0.009568, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 344: PDE Error: 0.009520, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 345: PDE Error: 0.009473, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 346: PDE Error: 0.009425, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 347: PDE Error: 0.009378, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 348: PDE Error: 0.009332, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 349: PDE Error: 0.009285, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 350: PDE Error: 0.009239, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 351: PDE Error: 0.009193, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 352: PDE Error: 0.009147, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 353: PDE Error: 0.009101, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 354: PDE Error: 0.009056, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 355: PDE Error: 0.009010, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 356: PDE Error: 0.008965, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 357: PDE Error: 0.008921, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 358: PDE Error: 0.008876, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 359: PDE Error: 0.008832, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 360: PDE Error: 0.008788, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 361: PDE Error: 0.008744, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 362: PDE Error: 0.008700, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 363: PDE Error: 0.008657, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 364: PDE Error: 0.008614, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 365: PDE Error: 0.008571, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 366: PDE Error: 0.008528, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 367: PDE Error: 0.008485, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 368: PDE Error: 0.008443, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 369: PDE Error: 0.008401, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 370: PDE Error: 0.008359, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 371: PDE Error: 0.008317, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 372: PDE Error: 0.008276, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 373: PDE Error: 0.008234, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 374: PDE Error: 0.008193, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 375: PDE Error: 0.008152, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 376: PDE Error: 0.008112, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 377: PDE Error: 0.008071, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 378: PDE Error: 0.008031, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 379: PDE Error: 0.007991, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 380: PDE Error: 0.007951, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 381: PDE Error: 0.007911, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 382: PDE Error: 0.007872, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 383: PDE Error: 0.007832, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 384: PDE Error: 0.007793, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 385: PDE Error: 0.007754, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 386: PDE Error: 0.007716, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 387: PDE Error: 0.007677, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 388: PDE Error: 0.007639, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 389: PDE Error: 0.007601, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 390: PDE Error: 0.007563, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 391: PDE Error: 0.007525, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 392: PDE Error: 0.007488, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 393: PDE Error: 0.007450, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 394: PDE Error: 0.007413, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 395: PDE Error: 0.007376, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 396: PDE Error: 0.007339, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 397: PDE Error: 0.007303, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 398: PDE Error: 0.007266, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 399: PDE Error: 0.007230, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 400: PDE Error: 0.007194, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 401: PDE Error: 0.007158, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 402: PDE Error: 0.007122, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 403: PDE Error: 0.007087, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 404: PDE Error: 0.007051, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 405: PDE Error: 0.007016, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 406: PDE Error: 0.006981, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 407: PDE Error: 0.006946, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 408: PDE Error: 0.006912, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 409: PDE Error: 0.006877, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 410: PDE Error: 0.006843, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 411: PDE Error: 0.006809, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 412: PDE Error: 0.006775, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 413: PDE Error: 0.006741, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 414: PDE Error: 0.006707, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 415: PDE Error: 0.006674, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 416: PDE Error: 0.006641, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 417: PDE Error: 0.006607, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 418: PDE Error: 0.006574, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 419: PDE Error: 0.006542, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 420: PDE Error: 0.006509, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 421: PDE Error: 0.006477, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 422: PDE Error: 0.006444, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 423: PDE Error: 0.006412, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 424: PDE Error: 0.006380, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 425: PDE Error: 0.006348, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 426: PDE Error: 0.006317, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 427: PDE Error: 0.006285, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 428: PDE Error: 0.006254, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 429: PDE Error: 0.006222, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 430: PDE Error: 0.006191, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 431: PDE Error: 0.006161, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 432: PDE Error: 0.006130, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 433: PDE Error: 0.006099, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 434: PDE Error: 0.006069, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 435: PDE Error: 0.006039, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 436: PDE Error: 0.006008, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 437: PDE Error: 0.005978, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 438: PDE Error: 0.005949, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 439: PDE Error: 0.005919, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 440: PDE Error: 0.005889, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 441: PDE Error: 0.005860, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 442: PDE Error: 0.005831, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 443: PDE Error: 0.005802, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 444: PDE Error: 0.005773, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 445: PDE Error: 0.005744, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 446: PDE Error: 0.005715, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 447: PDE Error: 0.005687, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 448: PDE Error: 0.005659, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 449: PDE Error: 0.005631, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 450: PDE Error: 0.005603, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 451: PDE Error: 0.005575, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 452: PDE Error: 0.005547, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 453: PDE Error: 0.005520, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 454: PDE Error: 0.005492, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 455: PDE Error: 0.005465, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 456: PDE Error: 0.005438, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 457: PDE Error: 0.005411, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 458: PDE Error: 0.005384, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 459: PDE Error: 0.005358, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 460: PDE Error: 0.005331, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 461: PDE Error: 0.005305, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 462: PDE Error: 0.005279, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 463: PDE Error: 0.005253, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 464: PDE Error: 0.005227, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 465: PDE Error: 0.005201, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 466: PDE Error: 0.005175, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 467: PDE Error: 0.005149, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 468: PDE Error: 0.005124, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 469: PDE Error: 0.005099, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 470: PDE Error: 0.005073, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 471: PDE Error: 0.005048, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 472: PDE Error: 0.005023, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 473: PDE Error: 0.004999, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 474: PDE Error: 0.004974, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 475: PDE Error: 0.004949, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 476: PDE Error: 0.004925, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 477: PDE Error: 0.004900, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 478: PDE Error: 0.004876, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 479: PDE Error: 0.004852, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 480: PDE Error: 0.004828, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 481: PDE Error: 0.004804, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 482: PDE Error: 0.004780, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 483: PDE Error: 0.004757, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 484: PDE Error: 0.004733, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 485: PDE Error: 0.004710, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 486: PDE Error: 0.004687, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 487: PDE Error: 0.004663, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 488: PDE Error: 0.004640, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 489: PDE Error: 0.004617, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 490: PDE Error: 0.004595, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 491: PDE Error: 0.004572, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 492: PDE Error: 0.004549, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 493: PDE Error: 0.004527, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 494: PDE Error: 0.004504, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 495: PDE Error: 0.004482, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 496: PDE Error: 0.004460, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 497: PDE Error: 0.004438, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 498: PDE Error: 0.004416, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 499: PDE Error: 0.004394, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 500: PDE Error: 0.004372, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 501: PDE Error: 0.004351, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 502: PDE Error: 0.004329, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 503: PDE Error: 0.004308, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 504: PDE Error: 0.004287, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 505: PDE Error: 0.004265, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 506: PDE Error: 0.004244, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 507: PDE Error: 0.004223, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 508: PDE Error: 0.004202, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 509: PDE Error: 0.004182, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 510: PDE Error: 0.004161, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 511: PDE Error: 0.004140, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 512: PDE Error: 0.004120, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 513: PDE Error: 0.004100, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 514: PDE Error: 0.004079, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 515: PDE Error: 0.004059, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 516: PDE Error: 0.004039, Conjugate Gradient Error 0.000000 after 5 iterations
# Episode 517: PDE Error: 0.004019, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 518: PDE Error: 0.003999, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 519: PDE Error: 0.003979, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 520: PDE Error: 0.003960, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 521: PDE Error: 0.003940, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 522: PDE Error: 0.003921, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 523: PDE Error: 0.003901, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 524: PDE Error: 0.003882, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 525: PDE Error: 0.003863, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 526: PDE Error: 0.003844, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 527: PDE Error: 0.003825, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 528: PDE Error: 0.003806, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 529: PDE Error: 0.003787, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 530: PDE Error: 0.003768, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 531: PDE Error: 0.003750, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 532: PDE Error: 0.003731, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 533: PDE Error: 0.003713, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 534: PDE Error: 0.003694, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 535: PDE Error: 0.003676, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 536: PDE Error: 0.003658, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 537: PDE Error: 0.003640, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 538: PDE Error: 0.003622, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 539: PDE Error: 0.003604, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 540: PDE Error: 0.003586, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 541: PDE Error: 0.003569, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 542: PDE Error: 0.003551, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 543: PDE Error: 0.003533, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 544: PDE Error: 0.003516, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 545: PDE Error: 0.003499, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 546: PDE Error: 0.003481, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 547: PDE Error: 0.003464, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 548: PDE Error: 0.003447, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 549: PDE Error: 0.003430, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 550: PDE Error: 0.003413, Conjugate Gradient Error 0.000000 after 4 iterations
# Episode 551: PDE Error: 0.003396, Conjugate Gradient Error 0.000000 after 4 iterations
# ...
# Episode 2022: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2023: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2024: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2025: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2026: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2027: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2028: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2029: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2030: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2031: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2032: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2033: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2034: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2035: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2036: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2037: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2038: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2039: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2040: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2041: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2042: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2043: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2044: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2045: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2046: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2047: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2048: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2049: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2050: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2051: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2052: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2053: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2054: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2055: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2056: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2057: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2058: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2059: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2060: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2061: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2062: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2063: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2064: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2065: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2066: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2067: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2068: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2069: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2070: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2071: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2072: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2073: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2074: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2075: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2076: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2077: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2078: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2079: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2080: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2081: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2082: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2083: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2084: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2085: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2086: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2087: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2088: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2089: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2090: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2091: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2092: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2093: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2094: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2095: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2096: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2097: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2098: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2099: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2100: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2101: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2102: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2103: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2104: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2105: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2106: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2107: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2108: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2109: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2110: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2111: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2112: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2113: PDE Error: 0.000002, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2114: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2115: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2116: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2117: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2118: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2119: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2120: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2121: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2122: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2123: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2124: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2125: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2126: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2127: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2128: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2129: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2130: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2131: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2132: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2133: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2134: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2135: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2136: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2137: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2138: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2139: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2140: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2141: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2142: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2143: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2144: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2145: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2146: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2147: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2148: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2149: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2150: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2151: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2152: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2153: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2154: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2155: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2156: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2157: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2158: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2159: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2160: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2161: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2162: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2163: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2164: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2165: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2166: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2167: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2168: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2169: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2170: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2171: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2172: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2173: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2174: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2175: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2176: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2177: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2178: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2179: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2180: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2181: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2182: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2183: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2184: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2185: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2186: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2187: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2188: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2189: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2190: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2191: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2192: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2193: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2194: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2195: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2196: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2197: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# Episode 2198: PDE Error: 0.000001, Conjugate Gradient Error 0.000000 after 1 iterations
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-301ec2f0e74e> in <module>
#     317     dt = dt
#     318
# --> 319     out = SolveLinSys.solvels(stateSpace, A,B,C,D,v01,dt)
#     320     out_comp = out[2].reshape(v0.shape,order = "F")
#     321     episode += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Jupyter noebook solves the model in 1084 seconds (3096 iterations) while MATLAB took about 200 seconds on my laptop. The differenceS of solved result and parameters are tiny as shown below.

# %%
for_check = loadmat('HJB_level_result.mat')
np.max(abs(for_check['out_comp'] - out_comp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-33745e4b80c6> in <module>
#       1 for_check = loadmat('HJB_level_result.mat')
# ----> 2 np.max(abs(for_check['out_comp'] - out_comp))
#
# NameError: name 'out_comp' is not defined

# %%
mdl = for_check['model']

# %%
np.max(abs(mdl['A'][0,0] - B))

# %%
np.max(abs(mdl['B'][0,0] - B))
# Out:
# 2.6314828679811775e-10

# %%
np.max(abs(mdl['C'][0,0] - C))
# Out:
# 0.0

# %%
np.max(abs(mdl['D'][0,0] - D))
# Out:
# 2.192690473634684e-15
